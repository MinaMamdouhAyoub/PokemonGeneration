# %% [markdown]
# Completly Trained and tested except frechet

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 15891, done.
# remote: Total 15891 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15891/15891), 733.46 MiB | 42.32 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1697/1697), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
_instance_scale=1.0
for data in val_generator:
    print(data['images'].numpy().max())
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
latents_dim
# Out:
# 100

# %%
enc_lays = [tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),

            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'AE_Dense_reconst_1ell_01psnr'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr

# %%
from training.autoencoding_basic.autoencoders.autoencoder import autoencoder as AE

# %%
variables_params = \
[
    {
        'name': 'inference', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': enc_lays
    }

    ,
    
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=None
    )
# Out:
#   WARNING  | None
#   WARNING  | None
#   WARNING  | None
#   WARNING  | None
# Model: "inference"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 50)      200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 50)      2550
# _________________________________________________________________
# flatten (Flatten)            (None, 500000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               50000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_outputs (Activatio (None, 100)               0
# =================================================================
# Total params: 50,003,250
# Trainable params: 50,003,050
# Non-trainable params: 200
# _________________________________________________________________
#
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1666)              168266
# _________________________________________________________________
# dense_5 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_6 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_7 (Dense)              (None, 30000)             50010000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 55,742,822
# Trainable params: 55,742,816
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.peak_signal_to_noise_ratio import prepare_psnr
#from statistical.losses_utilities import similarty_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
#ae.compile(metrics=None)
#ae.compile()
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+ 0.1*prepare_psnr([ae.batch_size]+ae.get_inputs_shape())(x_true, x_logits)})
# Out:
# Model: "pokemonAE_Dense_reconst_1ell_01psnr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inference (Functional)       (None, 100)               50003250
# _________________________________________________________________
# generative (Functional)      (None, 100, 100, 3)       55742822
# _________________________________________________________________
# tf_op_layer_x_logits (Tensor [(None, 100, 100, 3)]     0
# =================================================================
# Total params: 105,746,072
# Trainable params: 105,745,866
# Non-trainable params: 206
# _________________________________________________________________
# None

# %%
ae.output_shape
# Out:
# (None, 100, 100, 3)

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-15, 
    patience=10, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/csv_dir/pokemonAE_Dense_reconst_1ell_01psnr.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %%
import numpy as np

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=val_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 6615.27832, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 611s - loss: 6615.2783 - psnr: 11.3828 - total_variation: 86882.7422 - ssim_multiscale: 4.1664 - sharpdiff: 5.3027 - mean_absolute_error: 0.1982 - mean_squared_error: 0.0749 - val_loss: 5885.1040 - val_psnr: 12.3709 - val_total_variation: 22580.4297 - val_ssim_multiscale: 4.6512 - val_sharpdiff: 9.3184 - val_mean_absolute_error: 0.1776 - val_mean_squared_error: 0.0616
# Epoch 2/1000000
#
# Epoch 00002: loss improved from 6615.27832 to 4433.75098, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 603s - loss: 4433.7510 - psnr: 12.9162 - total_variation: 102431.9297 - ssim_multiscale: 6.3632 - sharpdiff: 5.1845 - mean_absolute_error: 0.1381 - mean_squared_error: 0.0518 - val_loss: 6498.8628 - val_psnr: 11.9831 - val_total_variation: 21438.9766 - val_ssim_multiscale: 4.1110 - val_sharpdiff: 9.2731 - val_mean_absolute_error: 0.2019 - val_mean_squared_error: 0.0666
# Epoch 3/1000000
#
# Epoch 00003: loss improved from 4433.75098 to 4156.22119, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 602s - loss: 4156.2212 - psnr: 13.1312 - total_variation: 103194.6484 - ssim_multiscale: 6.6553 - sharpdiff: 5.2531 - mean_absolute_error: 0.1278 - mean_squared_error: 0.0494 - val_loss: 6932.6836 - val_psnr: 11.6838 - val_total_variation: 20633.7539 - val_ssim_multiscale: 3.9148 - val_sharpdiff: 9.2861 - val_mean_absolute_error: 0.2161 - val_mean_squared_error: 0.0710
# Epoch 4/1000000
#
# Epoch 00004: loss improved from 4156.22119 to 4066.53174, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 599s - loss: 4066.5317 - psnr: 13.1962 - total_variation: 103091.3438 - ssim_multiscale: 6.7238 - sharpdiff: 5.2847 - mean_absolute_error: 0.1241 - mean_squared_error: 0.0487 - val_loss: 6057.4785 - val_psnr: 12.2670 - val_total_variation: 20502.6387 - val_ssim_multiscale: 4.5089 - val_sharpdiff: 9.4173 - val_mean_absolute_error: 0.1836 - val_mean_squared_error: 0.0629
# Epoch 5/1000000
#
# Epoch 00005: loss improved from 4066.53174 to 3999.67993, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 596s - loss: 3999.6799 - psnr: 13.2433 - total_variation: 102967.4531 - ssim_multiscale: 6.7626 - sharpdiff: 5.3058 - mean_absolute_error: 0.1215 - mean_squared_error: 0.0481 - val_loss: 6191.4253 - val_psnr: 12.1822 - val_total_variation: 21079.4629 - val_ssim_multiscale: 4.3732 - val_sharpdiff: 9.3327 - val_mean_absolute_error: 0.1933 - val_mean_squared_error: 0.0638
# Epoch 6/1000000
#
# Epoch 00006: loss improved from 3999.67993 to 3974.90234, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 597s - loss: 3974.9023 - psnr: 13.2724 - total_variation: 102854.4688 - ssim_multiscale: 6.7889 - sharpdiff: 5.3218 - mean_absolute_error: 0.1196 - mean_squared_error: 0.0479 - val_loss: 6072.1240 - val_psnr: 12.2213 - val_total_variation: 18112.2520 - val_ssim_multiscale: 4.6320 - val_sharpdiff: 9.6630 - val_mean_absolute_error: 0.1783 - val_mean_squared_error: 0.0644
# Epoch 7/1000000
#
# Epoch 00007: loss improved from 3974.90234 to 3928.98364, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 595s - loss: 3928.9836 - psnr: 13.3059 - total_variation: 102791.6250 - ssim_multiscale: 6.8078 - sharpdiff: 5.3337 - mean_absolute_error: 0.1176 - mean_squared_error: 0.0475 - val_loss: 6319.1372 - val_psnr: 12.0570 - val_total_variation: 16542.3848 - val_ssim_multiscale: 4.3408 - val_sharpdiff: 9.7269 - val_mean_absolute_error: 0.1908 - val_mean_squared_error: 0.0670
# Epoch 8/1000000
#
# Epoch 00008: loss improved from 3928.98364 to 3900.27734, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 595s - loss: 3900.2773 - psnr: 13.3276 - total_variation: 102732.5469 - ssim_multiscale: 6.8242 - sharpdiff: 5.3436 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0472 - val_loss: 6968.3027 - val_psnr: 11.5393 - val_total_variation: 12701.5225 - val_ssim_multiscale: 4.1178 - val_sharpdiff: 10.0478 - val_mean_absolute_error: 0.1966 - val_mean_squared_error: 0.0767
# Epoch 9/1000000
#
# Epoch 00009: loss improved from 3900.27734 to 3892.57080, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 595s - loss: 3892.5708 - psnr: 13.3402 - total_variation: 102676.0781 - ssim_multiscale: 6.8338 - sharpdiff: 5.3518 - mean_absolute_error: 0.1149 - mean_squared_error: 0.0471 - val_loss: 8068.2866 - val_psnr: 10.8855 - val_total_variation: 8818.7129 - val_ssim_multiscale: 3.5217 - val_sharpdiff: 10.2914 - val_mean_absolute_error: 0.2144 - val_mean_squared_error: 0.0902
# Epoch 10/1000000
#
# Epoch 00010: loss improved from 3892.57080 to 3863.05493, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 598s - loss: 3863.0549 - psnr: 13.3549 - total_variation: 102636.9375 - ssim_multiscale: 6.8421 - sharpdiff: 5.3572 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0469 - val_loss: 7901.8018 - val_psnr: 10.9851 - val_total_variation: 9946.8389 - val_ssim_multiscale: 3.6403 - val_sharpdiff: 10.2225 - val_mean_absolute_error: 0.2109 - val_mean_squared_error: 0.0881
# Epoch 11/1000000
#
# Epoch 00011: loss improved from 3863.05493 to 3860.80835, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01psnr/var_save_dir
# 5000/5000 - 597s - loss: 3860.8083 - psnr: 13.3630 - total_variation: 102553.1250 - ssim_multiscale: 6.8488 - sharpdiff: 5.3648 - mean_absolute_error: 0.1132 - mean_squared_error: 0.0469 - val_loss: 7927.2729 - val_psnr: 10.9917 - val_total_variation: 10344.7588 - val_ssim_multiscale: 3.5817 - val_sharpdiff: 10.1767 - val_mean_absolute_error: 0.2138 - val_mean_squared_error: 0.0880
# Epoch 00011: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:17:14, 26.65s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 300it [2:15:07, 26.84s/it]
# inception_score mean: [1.38139321e+121], sigma: 2.25826432520851e+243

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)
# Out:
# calculating the inception images sigma ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_4:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/array/routines.py:272: PerformanceWarning: Increasing number of chunks by factor of 205
#   axes=(left_axes, right_axes),
# 1it [00:55, 55.31s/it]/usr/local/lib/python3.6/dist-packages/dask/array/routines.py:272: PerformanceWarning: Increasing number of chunks by factor of 205
#   axes=(left_axes, right_axes),
# 2it [02:23, 65.08s/it]/usr/local/lib/python3.6/dist-packages/dask/array/routines.py:272: PerformanceWarning: Increasing number of chunks by factor of 205
#   axes=(left_axes, right_axes),
# 0it [00:00, ?it/s]
# calculating the inception images mean ...
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/array/routines.py:272: PerformanceWarning: Increasing number of chunks by factor of 205
#   axes=(left_axes, right_axes),
# calculating the generated images sigma ...
# 1it [00:55, 55.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/routines.py:272: PerformanceWarning: Increasing number of chunks by factor of 205
#   axes=(left_axes, right_axes),
# 2it [02:23, 65.13s/it]/usr/local/lib/python3.6/dist-packages/dask/array/routines.py:272: PerformanceWarning: Increasing number of chunks by factor of 205
#   axes=(left_axes, right_axes),
# 0it [00:00, ?it/s]
# calculating the generated images mean ...

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 300it [04:33,  1.10it/s]
# perceptual path length score: 5073.28369140625

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00252962s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.0019176s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00207829s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00244904s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 48.87it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 95.48it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 40.84it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 49.63it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 79.42it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 132.22it/s]
# 10it [00:00, 139.34it/s]
# 0it [00:00, ?it/s]
# 10it [00:00, 116.68it/s]
# 10it [00:00, 128.54it/s]
# 100%|██████████| 4/4 [00:00<00:00, 10.87it/s]
# 10it [00:00, 124.93it/s]
