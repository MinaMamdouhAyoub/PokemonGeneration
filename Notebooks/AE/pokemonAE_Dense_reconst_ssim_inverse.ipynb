# %% [markdown]
# **Trained and tested except Frechet**

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# fatal: destination path 'Generative_Models' already exists and is not an empty directory.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
_instance_scale=1.0
for data in val_generator:
    print(data['images'].numpy().max())
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
latents_dim
# Out:
# 100

# %%
enc_lays = [tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),

            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'AE_Dense_reconst_ssim_inverse'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse

# %%
from training.autoencoding_basic.autoencoders.autoencoder import autoencoder as AE

# %%
variables_params = \
[
    {
        'name': 'inference', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': enc_lays
    }

    ,
    
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   ERROR    | Faild to restore old models !
#   ERROR    | Faild to restore old models !
#   WARNING  | None
#   WARNING  | None
# SavedModel file does not exist at: /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir/pokemonAE_Dense_reconst_ssim_inverse_inference.hdf5/{saved_model.pbtxt|saved_model.pb}
#
#
# Model: "inference"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 50)      200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 50)      2550
# _________________________________________________________________
# flatten (Flatten)            (None, 500000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               50000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_outputs (Activatio (None, 100)               0
# =================================================================
# Total params: 50,003,250
# Trainable params: 50,003,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1666)              168266
# _________________________________________________________________
# dense_5 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_6 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_7 (Dense)              (None, 30000)             50010000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 55,742,822
# Trainable params: 55,742,816
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.structural_similarity import prepare_ssim_multiscale

#from statistical.losses_utilities import similarty_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
def similarity_to_distance(similarity_fn):
    distance_fn = lambda x, y: 0.5*(1-similarity_fn(x,y))
    return distance_fn

ssim = similarity_to_distance(prepare_ssim_multiscale([ae.batch_size]+ae.get_inputs_shape()))

# %%
#ae.compile(metrics=None)
#ae.compile()
ae.compile(loss={'x_logits': lambda x_true, x_logits: ssim(x_true, x_logits)})
# Out:
# Model: "pokemonAE_Dense_reconst_ssim_inverse"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inference (Functional)       (None, 100)               50003250
# _________________________________________________________________
# generative (Functional)      (None, 100, 100, 3)       55742822
# _________________________________________________________________
# tf_op_layer_x_logits (Tensor [(None, 100, 100, 3)]     0
# =================================================================
# Total params: 105,746,072
# Trainable params: 105,745,866
# Non-trainable params: 206
# _________________________________________________________________
# None

# %%
ae.output_shape
# Out:
# (None, 100, 100, 3)

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-15, 
    patience=10, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/csv_dir/pokemonAE_Dense_reconst_ssim_inverse.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %%
import numpy as np

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=val_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:297: setdiff1d (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# This op will be removed after the deprecation date. Please switch to tf.sets.difference().
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0381s vs `on_train_batch_end` time: 0.0695s). Check your callbacks.
#
# Epoch 00001: loss improved from inf to -2.20064, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 651s - loss: -2.2006e+00 - psnr: 11.0902 - total_variation: 95345.1719 - ssim_multiscale: 5.6901 - sharpdiff: 5.2676 - mean_absolute_error: 0.2230 - mean_squared_error: 0.0833 - val_loss: -1.0802e+00 - val_psnr: 10.2640 - val_total_variation: 18152.4785 - val_ssim_multiscale: 3.2459 - val_sharpdiff: 9.3705 - val_mean_absolute_error: 0.2790 - val_mean_squared_error: 0.0958
# Epoch 2/1000000
#
# Epoch 00002: loss improved from -2.20064 to -2.68491, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 651s - loss: -2.6849e+00 - psnr: 12.3217 - total_variation: 97123.1016 - ssim_multiscale: 6.7080 - sharpdiff: 5.3674 - mean_absolute_error: 0.1791 - mean_squared_error: 0.0596 - val_loss: -1.0629e+00 - val_psnr: 10.0449 - val_total_variation: 14773.6035 - val_ssim_multiscale: 3.1997 - val_sharpdiff: 9.6233 - val_mean_absolute_error: 0.2879 - val_mean_squared_error: 0.1007
# Epoch 3/1000000
#
# Epoch 00003: loss improved from -2.68491 to -2.72585, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 651s - loss: -2.7258e+00 - psnr: 12.4228 - total_variation: 95462.8203 - ssim_multiscale: 6.7871 - sharpdiff: 5.4592 - mean_absolute_error: 0.1761 - mean_squared_error: 0.0583 - val_loss: -1.1183e+00 - val_psnr: 10.2613 - val_total_variation: 13875.9404 - val_ssim_multiscale: 3.3171 - val_sharpdiff: 9.7011 - val_mean_absolute_error: 0.2806 - val_mean_squared_error: 0.0960
# Epoch 4/1000000
#
# Epoch 00004: loss improved from -2.72585 to -2.74523, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 651s - loss: -2.7452e+00 - psnr: 12.4723 - total_variation: 94670.4375 - ssim_multiscale: 6.8237 - sharpdiff: 5.5041 - mean_absolute_error: 0.1745 - mean_squared_error: 0.0576 - val_loss: -1.0892e+00 - val_psnr: 10.1174 - val_total_variation: 12107.7227 - val_ssim_multiscale: 3.2495 - val_sharpdiff: 9.8375 - val_mean_absolute_error: 0.2870 - val_mean_squared_error: 0.0993
# Epoch 5/1000000
#
# Epoch 00005: loss improved from -2.74523 to -2.75713, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 651s - loss: -2.7571e+00 - psnr: 12.5025 - total_variation: 94287.7578 - ssim_multiscale: 6.8455 - sharpdiff: 5.5282 - mean_absolute_error: 0.1734 - mean_squared_error: 0.0573 - val_loss: -1.2649e+00 - val_psnr: 10.6421 - val_total_variation: 13683.4365 - val_ssim_multiscale: 3.6279 - val_sharpdiff: 9.7841 - val_mean_absolute_error: 0.2646 - val_mean_squared_error: 0.0878
# Epoch 6/1000000
#
# Epoch 00006: loss improved from -2.75713 to -2.76698, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 653s - loss: -2.7670e+00 - psnr: 12.5240 - total_variation: 93978.0000 - ssim_multiscale: 6.8628 - sharpdiff: 5.5457 - mean_absolute_error: 0.1728 - mean_squared_error: 0.0570 - val_loss: -1.3632e+00 - val_psnr: 10.9762 - val_total_variation: 13893.2725 - val_ssim_multiscale: 3.8497 - val_sharpdiff: 9.8181 - val_mean_absolute_error: 0.2491 - val_mean_squared_error: 0.0812
# Epoch 7/1000000
#
# Epoch 00007: loss improved from -2.76698 to -2.77364, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 664s - loss: -2.7736e+00 - psnr: 12.5429 - total_variation: 93811.7891 - ssim_multiscale: 6.8741 - sharpdiff: 5.5572 - mean_absolute_error: 0.1721 - mean_squared_error: 0.0567 - val_loss: -1.4872e+00 - val_psnr: 11.3318 - val_total_variation: 14753.4336 - val_ssim_multiscale: 4.1333 - val_sharpdiff: 9.8042 - val_mean_absolute_error: 0.2323 - val_mean_squared_error: 0.0749
# Epoch 8/1000000
#
# Epoch 00008: loss improved from -2.77364 to -2.78101, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 660s - loss: -2.7810e+00 - psnr: 12.5628 - total_variation: 93647.3047 - ssim_multiscale: 6.8869 - sharpdiff: 5.5676 - mean_absolute_error: 0.1714 - mean_squared_error: 0.0564 - val_loss: -1.4186e+00 - val_psnr: 11.2714 - val_total_variation: 13151.9600 - val_ssim_multiscale: 3.9755 - val_sharpdiff: 9.9132 - val_mean_absolute_error: 0.2399 - val_mean_squared_error: 0.0763
# Epoch 9/1000000
#
# Epoch 00009: loss improved from -2.78101 to -2.78556, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 653s - loss: -2.7856e+00 - psnr: 12.5726 - total_variation: 93487.7422 - ssim_multiscale: 6.8940 - sharpdiff: 5.5767 - mean_absolute_error: 0.1712 - mean_squared_error: 0.0563 - val_loss: -1.2920e+00 - val_psnr: 11.0836 - val_total_variation: 10683.7061 - val_ssim_multiscale: 3.6993 - val_sharpdiff: 10.0682 - val_mean_absolute_error: 0.2521 - val_mean_squared_error: 0.0803
# Epoch 10/1000000
#
# Epoch 00010: loss improved from -2.78556 to -2.78969, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 650s - loss: -2.7897e+00 - psnr: 12.5836 - total_variation: 93394.8125 - ssim_multiscale: 6.9013 - sharpdiff: 5.5823 - mean_absolute_error: 0.1708 - mean_squared_error: 0.0562 - val_loss: -1.2205e+00 - val_psnr: 10.8682 - val_total_variation: 10039.9355 - val_ssim_multiscale: 3.5503 - val_sharpdiff: 10.0945 - val_mean_absolute_error: 0.2597 - val_mean_squared_error: 0.0843
# Epoch 11/1000000
#
# Epoch 00011: loss improved from -2.78969 to -2.79143, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 658s - loss: -2.7914e+00 - psnr: 12.5851 - total_variation: 93228.8906 - ssim_multiscale: 6.9040 - sharpdiff: 5.5913 - mean_absolute_error: 0.1708 - mean_squared_error: 0.0562 - val_loss: -1.1634e+00 - val_psnr: 10.7708 - val_total_variation: 9554.3369 - val_ssim_multiscale: 3.4297 - val_sharpdiff: 10.1111 - val_mean_absolute_error: 0.2645 - val_mean_squared_error: 0.0866
# Epoch 12/1000000
#
# Epoch 00012: loss improved from -2.79143 to -2.79295, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 648s - loss: -2.7930e+00 - psnr: 12.5877 - total_variation: 93111.7812 - ssim_multiscale: 6.9068 - sharpdiff: 5.5982 - mean_absolute_error: 0.1707 - mean_squared_error: 0.0562 - val_loss: -1.1369e+00 - val_psnr: 10.7095 - val_total_variation: 8572.2295 - val_ssim_multiscale: 3.3720 - val_sharpdiff: 10.1940 - val_mean_absolute_error: 0.2673 - val_mean_squared_error: 0.0875
# Epoch 13/1000000
#
# Epoch 00013: loss improved from -2.79295 to -2.79481, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 649s - loss: -2.7948e+00 - psnr: 12.5879 - total_variation: 92995.2109 - ssim_multiscale: 6.9102 - sharpdiff: 5.6035 - mean_absolute_error: 0.1708 - mean_squared_error: 0.0562 - val_loss: -1.1351e+00 - val_psnr: 10.6765 - val_total_variation: 9087.5508 - val_ssim_multiscale: 3.3702 - val_sharpdiff: 10.1443 - val_mean_absolute_error: 0.2676 - val_mean_squared_error: 0.0882
# Epoch 14/1000000
#
# Epoch 00014: loss improved from -2.79481 to -2.79638, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 649s - loss: -2.7964e+00 - psnr: 12.5916 - total_variation: 92931.1250 - ssim_multiscale: 6.9132 - sharpdiff: 5.6079 - mean_absolute_error: 0.1706 - mean_squared_error: 0.0561 - val_loss: -1.1608e+00 - val_psnr: 10.7369 - val_total_variation: 9418.5156 - val_ssim_multiscale: 3.4264 - val_sharpdiff: 10.1269 - val_mean_absolute_error: 0.2650 - val_mean_squared_error: 0.0874
# Epoch 15/1000000
#
# Epoch 00015: loss did not improve from -2.79638
# 5000/5000 - 648s - loss: -2.7958e+00 - psnr: 12.5889 - total_variation: 92821.1250 - ssim_multiscale: 6.9117 - sharpdiff: 5.6133 - mean_absolute_error: 0.1708 - mean_squared_error: 0.0562 - val_loss: -9.1090e-01 - val_psnr: 10.1642 - val_total_variation: 6734.9238 - val_ssim_multiscale: 2.8995 - val_sharpdiff: 10.2581 - val_mean_absolute_error: 0.2885 - val_mean_squared_error: 0.0991
# Epoch 16/1000000
#
# Epoch 00016: loss improved from -2.79638 to -2.79792, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 652s - loss: -2.7979e+00 - psnr: 12.5915 - total_variation: 92767.4297 - ssim_multiscale: 6.9158 - sharpdiff: 5.6170 - mean_absolute_error: 0.1707 - mean_squared_error: 0.0561 - val_loss: -1.1432e+00 - val_psnr: 10.7287 - val_total_variation: 9251.2383 - val_ssim_multiscale: 3.3928 - val_sharpdiff: 10.1303 - val_mean_absolute_error: 0.2653 - val_mean_squared_error: 0.0875
# Epoch 17/1000000
#
# Epoch 00017: loss improved from -2.79792 to -2.79854, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_ssim_inverse/var_save_dir
# 5000/5000 - 652s - loss: -2.7985e+00 - psnr: 12.5946 - total_variation: 92702.7188 - ssim_multiscale: 6.9171 - sharpdiff: 5.6208 - mean_absolute_error: 0.1706 - mean_squared_error: 0.0561 - val_loss: -1.1234e+00 - val_psnr: 10.6443 - val_total_variation: 9214.5264 - val_ssim_multiscale: 3.3586 - val_sharpdiff: 10.1337 - val_mean_absolute_error: 0.2675 - val_mean_squared_error: 0.0891
# Epoch 00017: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
17s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 261it [1:59:07, 28.12s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 262it [1:59:36, 28.13s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 263it [2:00:03, 27.98s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 264it [2:00:32, 28.12s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 265it [2:01:00, 28.14s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 266it [2:01:28, 28.22s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 267it [2:01:56, 28.21s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 268it [2:02:25, 28.26s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 269it [2:02:53, 28.30s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 270it [2:03:21, 28.12s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 271it [2:03:49, 28.08s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 272it [2:04:17, 28.13s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 273it [2:04:45, 28.02s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 274it [2:05:13, 28.17s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 275it [2:05:41, 28.11s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 276it [2:06:10, 28.18s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 277it [2:06:38, 28.18s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 278it [2:07:06, 28.27s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 279it [2:07:34, 28.16s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 280it [2:08:03, 28.27s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 281it [2:08:31, 28.20s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 282it [2:08:59, 28.14s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 283it [2:09:27, 28.11s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 284it [2:09:55, 28.08s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 285it [2:10:23, 28.08s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 286it [2:10:51, 28.12s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 287it [2:11:19, 28.06s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 288it [2:11:47, 28.11s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 289it [2:12:16, 28.14s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 290it [2:12:44, 28.17s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 291it [2:13:12, 28.10s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 292it [2:13:40, 28.17s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 293it [2:14:08, 28.08s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 294it [2:14:36, 28.21s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 295it [2:15:04, 28.11s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 296it [2:15:33, 28.16s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 297it [2:16:01, 28.10s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 298it [2:16:29, 28.10s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 299it [2:16:57, 28.09s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 300it [2:17:25, 28.12s/it]
# inception_score mean: [9.92040901e+168], sigma: inf

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 300it [04:29,  1.12it/s]
# perceptual path length score: 4936.9296875

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00166249s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00171447s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00188971s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00184464s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 39.45it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 43.07it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 43.23it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 45.45it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 92.74it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 113.82it/s]
# 10it [00:00, 140.13it/s]
# 0it [00:00, ?it/s]
# 10it [00:00, 135.68it/s]
# 10it [00:00, 138.32it/s]
# 100%|██████████| 4/4 [00:00<00:00, 10.90it/s]
# 10it [00:00, 145.66it/s]
