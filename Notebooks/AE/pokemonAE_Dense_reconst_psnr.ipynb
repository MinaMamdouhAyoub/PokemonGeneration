# %% [markdown]
# **Trained and tested except Frechet**

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 15891, done.
# remote: Total 15891 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15891/15891), 733.46 MiB | 45.84 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1697/1697), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
import numpy as np
_instance_scale=1.0
for data in val_generator:
    print(np.max(data['images']))
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
latents_dim
# Out:
# 100

# %%
enc_lays = [tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),

            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'AE_Dense_reconst_psnr'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr

# %%
from training.autoencoding_basic.autoencoders.autoencoder import autoencoder as AE

# %%
variables_params = \
[
    {
        'name': 'inference', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': enc_lays
    }

    ,
    
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   ERROR    | Faild to restore old models !
#   ERROR    | Faild to restore old models !
#   WARNING  | None
#   WARNING  | None
# SavedModel file does not exist at: /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir/pokemonAE_Dense_reconst_psnr_inference.hdf5/{saved_model.pbtxt|saved_model.pb}
#
#
# Model: "inference"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 50)      200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 50)      2550
# _________________________________________________________________
# flatten (Flatten)            (None, 500000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               50000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_outputs (Activatio (None, 100)               0
# =================================================================
# Total params: 50,003,250
# Trainable params: 50,003,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1666)              168266
# _________________________________________________________________
# dense_5 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_6 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_7 (Dense)              (None, 30000)             50010000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 55,742,822
# Trainable params: 55,742,816
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.peak_signal_to_noise_ratio import prepare_psnr
#from statistical.losses_utilities import similarty_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
#ae.compile(metrics=None)
#ae.compile()
ae.compile(loss={'x_logits': lambda x_true, x_logits: prepare_psnr([ae.batch_size]+ae.get_inputs_shape())(x_true, x_logits)})
# Out:
# Model: "pokemonAE_Dense_reconst_psnr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inference (Functional)       (None, 100)               50003250
# _________________________________________________________________
# generative (Functional)      (None, 100, 100, 3)       55742822
# _________________________________________________________________
# tf_op_layer_x_logits (Tensor [(None, 100, 100, 3)]     0
# =================================================================
# Total params: 105,746,072
# Trainable params: 105,745,866
# Non-trainable params: 206
# _________________________________________________________________
# None

# %%
ae.output_shape
# Out:
# (None, 100, 100, 3)

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-15, 
    patience=10, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/csv_dir/pokemonAE_Dense_reconst_psnr.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=val_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 3.36232, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 592s - loss: 3.3623 - psnr: 3.1129 - total_variation: 97443.8047 - ssim_multiscale: 0.0588 - sharpdiff: 4.6635 - mean_absolute_error: 0.6385 - mean_squared_error: 0.4982 - val_loss: 2.3288 - val_psnr: 2.0424 - val_total_variation: 16792.8281 - val_ssim_multiscale: 0.1873 - val_sharpdiff: 9.1081 - val_mean_absolute_error: 0.7377 - val_mean_squared_error: 0.6304
# Epoch 2/1000000
#
# Epoch 00002: loss improved from 3.36232 to 2.68097, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 593s - loss: 2.6810 - psnr: 2.2654 - total_variation: 115206.4531 - ssim_multiscale: 0.1245 - sharpdiff: 4.1804 - mean_absolute_error: 0.7138 - mean_squared_error: 0.5963 - val_loss: 2.3365 - val_psnr: 2.0504 - val_total_variation: 19559.1035 - val_ssim_multiscale: 0.2291 - val_sharpdiff: 8.9062 - val_mean_absolute_error: 0.7357 - val_mean_squared_error: 0.6287
# Epoch 3/1000000
#
# Epoch 00003: loss improved from 2.68097 to 2.58774, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 591s - loss: 2.5877 - psnr: 2.1711 - total_variation: 118345.4062 - ssim_multiscale: 0.1144 - sharpdiff: 4.1538 - mean_absolute_error: 0.7268 - mean_squared_error: 0.6091 - val_loss: 2.3968 - val_psnr: 2.1195 - val_total_variation: 24135.2715 - val_ssim_multiscale: 0.1412 - val_sharpdiff: 8.6078 - val_mean_absolute_error: 0.7280 - val_mean_squared_error: 0.6185
# Epoch 4/1000000
#
# Epoch 00004: loss improved from 2.58774 to 2.55716, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 592s - loss: 2.5572 - psnr: 2.1419 - total_variation: 119125.4297 - ssim_multiscale: 0.1116 - sharpdiff: 4.1472 - mean_absolute_error: 0.7308 - mean_squared_error: 0.6132 - val_loss: 2.3434 - val_psnr: 2.0460 - val_total_variation: 21225.3848 - val_ssim_multiscale: 0.2261 - val_sharpdiff: 8.8000 - val_mean_absolute_error: 0.7349 - val_mean_squared_error: 0.6292
# Epoch 5/1000000
#
# Epoch 00005: loss improved from 2.55716 to 2.54374, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 589s - loss: 2.5437 - psnr: 2.1294 - total_variation: 119336.7812 - ssim_multiscale: 0.1096 - sharpdiff: 4.1470 - mean_absolute_error: 0.7324 - mean_squared_error: 0.6149 - val_loss: 2.4098 - val_psnr: 2.1197 - val_total_variation: 24073.5742 - val_ssim_multiscale: 0.1565 - val_sharpdiff: 8.5939 - val_mean_absolute_error: 0.7276 - val_mean_squared_error: 0.6193
# Epoch 6/1000000
#
# Epoch 00006: loss improved from 2.54374 to 2.54000, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 594s - loss: 2.5400 - psnr: 2.1261 - total_variation: 119426.2109 - ssim_multiscale: 0.1109 - sharpdiff: 4.1478 - mean_absolute_error: 0.7329 - mean_squared_error: 0.6154 - val_loss: 2.3667 - val_psnr: 2.0619 - val_total_variation: 22236.2793 - val_ssim_multiscale: 0.2065 - val_sharpdiff: 8.7048 - val_mean_absolute_error: 0.7335 - val_mean_squared_error: 0.6272
# Epoch 7/1000000
#
# Epoch 00007: loss improved from 2.54000 to 2.53368, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 598s - loss: 2.5337 - psnr: 2.1202 - total_variation: 119512.9844 - ssim_multiscale: 0.1082 - sharpdiff: 4.1490 - mean_absolute_error: 0.7337 - mean_squared_error: 0.6162 - val_loss: 2.4520 - val_psnr: 2.1567 - val_total_variation: 24496.0703 - val_ssim_multiscale: 0.1291 - val_sharpdiff: 8.5511 - val_mean_absolute_error: 0.7232 - val_mean_squared_error: 0.6144
# Epoch 8/1000000
#
# Epoch 00008: loss improved from 2.53368 to 2.53051, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 602s - loss: 2.5305 - psnr: 2.1175 - total_variation: 119605.9766 - ssim_multiscale: 0.1084 - sharpdiff: 4.1500 - mean_absolute_error: 0.7340 - mean_squared_error: 0.6166 - val_loss: 2.6114 - val_psnr: 2.2496 - val_total_variation: 33987.6016 - val_ssim_multiscale: 0.0466 - val_sharpdiff: 7.8493 - val_mean_absolute_error: 0.7060 - val_mean_squared_error: 0.5997
# Epoch 9/1000000
#
# Epoch 00009: loss did not improve from 2.53051
# 5000/5000 - 603s - loss: 2.5537 - psnr: 2.1393 - total_variation: 119298.8047 - ssim_multiscale: 0.1060 - sharpdiff: 4.1604 - mean_absolute_error: 0.7315 - mean_squared_error: 0.6137 - val_loss: 2.6287 - val_psnr: 2.2876 - val_total_variation: 32464.9336 - val_ssim_multiscale: 0.2710 - val_sharpdiff: 8.0284 - val_mean_absolute_error: 0.7035 - val_mean_squared_error: 0.5965
# Epoch 10/1000000
#
# Epoch 00010: loss did not improve from 2.53051
# 5000/5000 - 602s - loss: 2.5349 - psnr: 2.1215 - total_variation: 119497.1016 - ssim_multiscale: 0.1054 - sharpdiff: 4.1566 - mean_absolute_error: 0.7335 - mean_squared_error: 0.6160 - val_loss: 2.3933 - val_psnr: 2.0476 - val_total_variation: 22366.0469 - val_ssim_multiscale: 0.4434 - val_sharpdiff: 8.6913 - val_mean_absolute_error: 0.7317 - val_mean_squared_error: 0.6294
# Epoch 11/1000000
#
# Epoch 00011: loss improved from 2.53051 to 2.52878, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr/var_save_dir
# 5000/5000 - 605s - loss: 2.5288 - psnr: 2.1157 - total_variation: 119615.9766 - ssim_multiscale: 0.1067 - sharpdiff: 4.1538 - mean_absolute_error: 0.7343 - mean_squared_error: 0.6169 - val_loss: 2.4579 - val_psnr: 2.1234 - val_total_variation: 25516.5352 - val_ssim_multiscale: 0.2666 - val_sharpdiff: 8.4825 - val_mean_absolute_error: 0.7254 - val_mean_squared_error: 0.6183
# Epoch 00011: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:20:39, 27.53s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 1it [00:27, 27.27s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 2it [00:54, 27.33s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 3it [01:21, 27.29s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 4it [01:48, 27.20s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 5it [02:16, 27.31s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 6it [02:43, 27.27s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 7it [03:10, 27.20s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 8it [03:38, 27.36s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 9it [04:05, 27.21s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 10it [04:32, 27.17s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 11it [04:59, 27.18s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 12it [05:26, 27.14s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 13it [05:53, 27.09s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 14it [06:20, 27.13s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 15it [06:47, 27.02s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 16it [07:14, 27.09s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 17it [07:41, 27.04s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 18it [08:08, 27.09s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 19it [08:35, 27.05s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 20it [09:03, 27.08s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 21it [09:30, 27.05s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 22it [09:56, 26.97s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 23it [10:24, 27.05s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 24it [10:51, 27.06s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 25it [11:18, 27.00s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 26it [11:44, 26.95s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 27it [12:11, 27.01s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 28it [12:39, 27.06s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 29it [13:06, 27.13s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 30it [13:33, 27.08s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 31it [14:00, 27.22s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 32it [14:27, 27.10s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 33it [14:55, 27.19s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 34it [15:22, 27.21s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 35it [15:49, 27.17s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 36it [16:17, 27.26s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 37it [16:44, 27.25s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 38it [17:11, 27.29s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 39it [17:38, 27.30s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 40it [18:06, 27.32s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 41it [18:33, 27.28s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
#
/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 278it [2:06:02, 27.22s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 279it [2:06:29, 27.24s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 280it [2:06:57, 27.26s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 281it [2:07:24, 27.32s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 282it [2:07:52, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 283it [2:08:20, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 284it [2:08:48, 27.62s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 285it [2:09:15, 27.70s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 286it [2:09:43, 27.73s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 287it [2:10:11, 27.81s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 288it [2:10:39, 27.70s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 289it [2:11:06, 27.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 290it [2:11:34, 27.79s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 291it [2:12:02, 27.86s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 292it [2:12:31, 27.92s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 293it [2:12:59, 27.97s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 294it [2:13:27, 28.01s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 295it [2:13:55, 27.95s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 296it [2:14:23, 28.06s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 297it [2:14:51, 27.99s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 298it [2:15:19, 28.04s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 299it [2:15:47, 28.00s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 300it [2:16:15, 28.07s/it]
# inception_score mean: [1.4813654e+186], sigma: inf

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 300it [04:51,  1.04it/s]
# perceptual path length score: 4903.8759765625

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# 0it [00:00, ?it/s]
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00216508s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.0022409s
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00245094s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00246978s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 54.14it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 38.38it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 41.03it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 46.90it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 75.75it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 117.34it/s]
# 10it [00:00, 133.39it/s]
# 0it [00:00, ?it/s]
# 10it [00:00, 123.68it/s]
# 10it [00:00, 124.23it/s]
# 100%|██████████| 4/4 [00:00<00:00, 10.65it/s]
# 10it [00:00, 122.88it/s]
