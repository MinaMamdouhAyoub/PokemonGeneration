# %% [markdown]
# Trained and tested except Frechet

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 15891, done.
# remote: Total 15891 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15891/15891), 733.46 MiB | 45.76 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1697/1697), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
_instance_scale=1.0
for data in val_generator:
    print(data['images'].numpy().max())
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
latents_dim
# Out:
# 100

# %%
enc_lays = [tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),

            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'AE_Dense_reconst_1ellwlb_01'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01

# %%
from training.autoencoding_basic.autoencoders.autoencoder import autoencoder as AE

# %%
variables_params = \
[
    {
        'name': 'inference', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': enc_lays
    }

    ,
    
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   WARNING  | None
#   WARNING  | None
# Model: "inference"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 50)      200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 50)      2550
# _________________________________________________________________
# flatten (Flatten)            (None, 500000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               50000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_outputs (Activatio (None, 100)               0
# =================================================================
# Total params: 50,003,250
# Trainable params: 50,003,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1666)              168266
# _________________________________________________________________
# dense_5 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_6 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_7 (Dense)              (None, 30000)             50010000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 55,742,822
# Trainable params: 55,742,816
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.peak_signal_to_noise_ratio import prepare_psnr
#from statistical.losses_utilities import similarty_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
#ae.compile(metrics=None)
#ae.compile()
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+ 0.1*prepare_psnr([ae.batch_size]+ae.get_inputs_shape())(x_true, x_logits)})
# Out:
# Model: "pokemonpokemonAE_Dense_reconst_1ellwlb_01"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inference (Functional)       (None, 100)               50003250
# _________________________________________________________________
# generative (Functional)      (None, 100, 100, 3)       55742822
# _________________________________________________________________
# tf_op_layer_x_logits (Tensor [(None, 100, 100, 3)]     0
# =================================================================
# Total params: 105,746,072
# Trainable params: 105,745,866
# Non-trainable params: 206
# _________________________________________________________________
# None

# %%
ae.output_shape
# Out:
# (None, 100, 100, 3)

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-15, 
    patience=10, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/csv_dir/pokemonpokemonAE_Dense_reconst_1ellwlb_01.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %%
import numpy as np

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=val_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 3871.39233, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 601s - loss: 3871.3923 - psnr: 13.3538 - total_variation: 102582.4531 - ssim_multiscale: 6.8440 - sharpdiff: 5.3606 - mean_absolute_error: 0.1140 - mean_squared_error: 0.0470 - val_loss: 7773.0933 - val_psnr: 11.0798 - val_total_variation: 10389.0674 - val_ssim_multiscale: 3.5983 - val_sharpdiff: 10.1594 - val_mean_absolute_error: 0.2136 - val_mean_squared_error: 0.0861
# Epoch 2/1000000
#
# Epoch 00002: loss improved from 3871.39233 to 3864.27783, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 605s - loss: 3864.2778 - psnr: 13.3561 - total_variation: 102722.7969 - ssim_multiscale: 6.8430 - sharpdiff: 5.3535 - mean_absolute_error: 0.1138 - mean_squared_error: 0.0469 - val_loss: 7750.7627 - val_psnr: 11.0882 - val_total_variation: 10671.4199 - val_ssim_multiscale: 3.6926 - val_sharpdiff: 10.1564 - val_mean_absolute_error: 0.2098 - val_mean_squared_error: 0.0860
# Epoch 3/1000000
#
# Epoch 00003: loss did not improve from 3864.27783
# 5000/5000 - 602s - loss: 3871.5596 - psnr: 13.3577 - total_variation: 102617.3828 - ssim_multiscale: 6.8472 - sharpdiff: 5.3607 - mean_absolute_error: 0.1134 - mean_squared_error: 0.0470 - val_loss: 8442.9082 - val_psnr: 10.7311 - val_total_variation: 8249.1396 - val_ssim_multiscale: 3.2990 - val_sharpdiff: 10.3143 - val_mean_absolute_error: 0.2214 - val_mean_squared_error: 0.0939
# Epoch 4/1000000
#
# Epoch 00004: loss improved from 3864.27783 to 3856.31372, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 601s - loss: 3856.3137 - psnr: 13.3680 - total_variation: 102577.6094 - ssim_multiscale: 6.8522 - sharpdiff: 5.3658 - mean_absolute_error: 0.1126 - mean_squared_error: 0.0468 - val_loss: 8071.4868 - val_psnr: 10.9323 - val_total_variation: 9675.2295 - val_ssim_multiscale: 3.4117 - val_sharpdiff: 10.2001 - val_mean_absolute_error: 0.2201 - val_mean_squared_error: 0.0892
# Epoch 5/1000000
#
# Epoch 00005: loss improved from 3856.31372 to 3835.36865, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 598s - loss: 3835.3687 - psnr: 13.3783 - total_variation: 102537.2578 - ssim_multiscale: 6.8581 - sharpdiff: 5.3705 - mean_absolute_error: 0.1119 - mean_squared_error: 0.0467 - val_loss: 8113.6914 - val_psnr: 10.8967 - val_total_variation: 9631.3779 - val_ssim_multiscale: 3.5223 - val_sharpdiff: 10.2303 - val_mean_absolute_error: 0.2148 - val_mean_squared_error: 0.0900
# Epoch 6/1000000
#
# Epoch 00006: loss did not improve from 3835.36865
# 5000/5000 - 598s - loss: 3846.0300 - psnr: 13.3768 - total_variation: 102472.5234 - ssim_multiscale: 6.8606 - sharpdiff: 5.3745 - mean_absolute_error: 0.1117 - mean_squared_error: 0.0468 - val_loss: 8347.0000 - val_psnr: 10.7857 - val_total_variation: 8728.7266 - val_ssim_multiscale: 3.3102 - val_sharpdiff: 10.2694 - val_mean_absolute_error: 0.2215 - val_mean_squared_error: 0.0924
# Epoch 7/1000000
#
# Epoch 00007: loss improved from 3835.36865 to 3827.62524, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 599s - loss: 3827.6252 - psnr: 13.3885 - total_variation: 102387.5156 - ssim_multiscale: 6.8660 - sharpdiff: 5.3812 - mean_absolute_error: 0.1110 - mean_squared_error: 0.0466 - val_loss: 8132.5000 - val_psnr: 10.8880 - val_total_variation: 9427.0957 - val_ssim_multiscale: 3.5409 - val_sharpdiff: 10.2505 - val_mean_absolute_error: 0.2144 - val_mean_squared_error: 0.0905
# Epoch 8/1000000
#
# Epoch 00008: loss improved from 3827.62524 to 3823.18921, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 599s - loss: 3823.1892 - psnr: 13.3905 - total_variation: 102357.4531 - ssim_multiscale: 6.8689 - sharpdiff: 5.3841 - mean_absolute_error: 0.1107 - mean_squared_error: 0.0466 - val_loss: 7991.5332 - val_psnr: 10.9659 - val_total_variation: 10185.2402 - val_ssim_multiscale: 3.5180 - val_sharpdiff: 10.1751 - val_mean_absolute_error: 0.2159 - val_mean_squared_error: 0.0884
# Epoch 9/1000000
#
# Epoch 00009: loss did not improve from 3823.18921
# 5000/5000 - 598s - loss: 3830.5923 - psnr: 13.3903 - total_variation: 102317.2188 - ssim_multiscale: 6.8701 - sharpdiff: 5.3868 - mean_absolute_error: 0.1106 - mean_squared_error: 0.0466 - val_loss: 8663.5879 - val_psnr: 10.6377 - val_total_variation: 8071.4634 - val_ssim_multiscale: 3.2658 - val_sharpdiff: 10.3348 - val_mean_absolute_error: 0.2218 - val_mean_squared_error: 0.0961
# Epoch 10/1000000
#
# Epoch 00010: loss improved from 3823.18921 to 3810.50781, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 598s - loss: 3810.5078 - psnr: 13.3983 - total_variation: 102288.9062 - ssim_multiscale: 6.8738 - sharpdiff: 5.3896 - mean_absolute_error: 0.1100 - mean_squared_error: 0.0465 - val_loss: 8585.4844 - val_psnr: 10.6625 - val_total_variation: 8274.1611 - val_ssim_multiscale: 3.3345 - val_sharpdiff: 10.3456 - val_mean_absolute_error: 0.2195 - val_mean_squared_error: 0.0954
# Epoch 11/1000000
#
# Epoch 00011: loss did not improve from 3810.50781
# 5000/5000 - 597s - loss: 3816.8496 - psnr: 13.3986 - total_variation: 102230.4453 - ssim_multiscale: 6.8756 - sharpdiff: 5.3935 - mean_absolute_error: 0.1099 - mean_squared_error: 0.0465 - val_loss: 8494.2275 - val_psnr: 10.7219 - val_total_variation: 8810.7832 - val_ssim_multiscale: 3.3501 - val_sharpdiff: 10.2887 - val_mean_absolute_error: 0.2192 - val_mean_squared_error: 0.0939
# Epoch 12/1000000
#
# Epoch 00012: loss improved from 3810.50781 to 3803.61353, saving model to /content/drive/My Drive/Results/pokemonpokemonAE_Dense_reconst_1ellwlb_01/var_save_dir
# 5000/5000 - 604s - loss: 3803.6135 - psnr: 13.4032 - total_variation: 102258.8750 - ssim_multiscale: 6.8751 - sharpdiff: 5.3940 - mean_absolute_error: 0.1095 - mean_squared_error: 0.0464 - val_loss: 8706.5635 - val_psnr: 10.6238 - val_total_variation: 8067.3335 - val_ssim_multiscale: 3.2277 - val_sharpdiff: 10.3371 - val_mean_absolute_error: 0.2227 - val_mean_squared_error: 0.0963
# Epoch 00012: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:18:19, 26.80s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 1it [00:26, 26.70s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 2it [00:53, 26.68s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 3it [01:20, 26.76s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 4it [01:46, 26.67s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 5it [02:13, 26.73s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 6it [02:40, 26.67s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 7it [03:07, 26.74s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 8it [03:33, 26.68s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 9it [04:00, 26.79s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 10it [04:27, 26.80s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 11it [04:54, 26.83s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 12it [05:21, 26.83s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 13it [05:47, 26.76s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 14it [06:14, 26.76s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 15it [06:41, 26.73s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 16it [07:07, 26.72s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 17it [07:34, 26.68s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 18it [08:01, 26.72s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 19it [08:27, 26.67s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 20it [08:54, 26.78s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 21it [09:21, 26.83s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 22it [09:48, 26.86s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 23it [10:15, 26.75s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 24it [10:42, 26.77s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 25it [11:08, 26.72s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 26it [11:35, 26.80s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 27it [12:02, 26.76s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 28it [12:29, 26.81s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 29it [12:56, 26.85s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 30it [13:22, 26.80s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 31it [13:49, 26.78s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 32it [14:16, 26.80s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 33it [14:43, 26.95s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 34it [15:10, 26.85s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 35it [15:37, 26.82s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 36it [16:03, 26.78s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 37it [16:30, 26.82s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 38it [16:57, 26.75s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 39it [17:24, 26.78s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 40it [17:50, 26.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 41it [18:17, 26.80s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 42it [18:44, 26.81s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 43it [19:11, 26.78s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 44it [19:37, 26.75s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
#
/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 299it [2:12:45, 26.62s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 300it [2:13:11, 26.52s/it]
# inception_score mean: [6.91512587e+178], sigma: inf

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-40b7a1c014a0> in <module>()
# ----> 1 fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(),
#       2                                        tolerance_threshold=1e-6,
#       3                                        max_iteration=3,
#       4                                        batch_size=32)
#
# NameError: name 'frechet_inception_distance' is not defined

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 300it [04:30,  1.12it/s]
# perceptual path length score: 5077.5146484375

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00238824s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00192547s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00192714s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00177145s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 69.46it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 41.62it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 50.31it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 43.85it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 96.67it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 138.35it/s]
# 10it [00:00, 142.13it/s]
# 0it [00:00, ?it/s]
# 10it [00:00, 139.64it/s]
# 10it [00:00, 143.66it/s]
# 100%|██████████| 4/4 [00:00<00:00, 11.75it/s]
# 10it [00:00, 140.54it/s]
