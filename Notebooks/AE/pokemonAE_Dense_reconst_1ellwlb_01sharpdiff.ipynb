# %% [markdown]
# Trained and tested except Frechet

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 15891, done.
# remote: Total 15891 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15891/15891), 733.46 MiB | 44.36 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1697/1697), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
import numpy as np
_instance_scale=1.0
for data in val_generator:
    print(np.max(data['images']))
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
latents_dim
# Out:
# 100

# %%
enc_lays = [tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),

            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'AE_Dense_reconst_1ell_01sharpdiff'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff

# %%
from training.autoencoding_basic.autoencoders.autoencoder import autoencoder as AE

# %%
variables_params = \
[
    {
        'name': 'inference', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': enc_lays
    }

    ,
    
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   WARNING  | None
#   WARNING  | None
# Model: "inference"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 50)      200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 50)      2550
# _________________________________________________________________
# flatten (Flatten)            (None, 500000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               50000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_outputs (Activatio (None, 100)               0
# =================================================================
# Total params: 50,003,250
# Trainable params: 50,003,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1666)              168266
# _________________________________________________________________
# dense_5 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_6 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_7 (Dense)              (None, 30000)             50010000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 55,742,822
# Trainable params: 55,742,816
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.sharp_difference import prepare_sharpdiff

#from statistical.losses_utilities import similarty_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
#ae.compile(metrics=None)
#ae.compile()
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+ 0.1*prepare_sharpdiff([ae.batch_size]+ae.get_inputs_shape())(x_true, x_logits)})
# Out:
# Model: "pokemonAE_Dense_reconst_1ell_01sharpdiff"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inference (Functional)       (None, 100)               50003250
# _________________________________________________________________
# generative (Functional)      (None, 100, 100, 3)       55742822
# _________________________________________________________________
# tf_op_layer_x_logits (Tensor [(None, 100, 100, 3)]     0
# =================================================================
# Total params: 105,746,072
# Trainable params: 105,745,866
# Non-trainable params: 206
# _________________________________________________________________
# None

# %%
ae.output_shape
# Out:
# (None, 100, 100, 3)

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-15, 
    patience=10, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/csv_dir/pokemonAE_Dense_reconst_1ell_01sharpdiff.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %%
import numpy as np

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=val_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 4000.88159, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 612s - loss: 4000.8816 - psnr: 13.2424 - total_variation: 102658.3672 - ssim_multiscale: 6.7675 - sharpdiff: 5.3225 - mean_absolute_error: 0.1214 - mean_squared_error: 0.0482 - val_loss: 6251.0254 - val_psnr: 12.1432 - val_total_variation: 22254.9453 - val_ssim_multiscale: 4.3933 - val_sharpdiff: 9.2693 - val_mean_absolute_error: 0.1865 - val_mean_squared_error: 0.0644
# Epoch 2/1000000
#
# Epoch 00002: loss improved from 4000.88159 to 3966.60840, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 615s - loss: 3966.6084 - psnr: 13.2726 - total_variation: 102759.2969 - ssim_multiscale: 6.7876 - sharpdiff: 5.3245 - mean_absolute_error: 0.1197 - mean_squared_error: 0.0478 - val_loss: 5849.5669 - val_psnr: 12.3519 - val_total_variation: 21044.7227 - val_ssim_multiscale: 4.7056 - val_sharpdiff: 9.4176 - val_mean_absolute_error: 0.1763 - val_mean_squared_error: 0.0611
# Epoch 3/1000000
#
# Epoch 00003: loss improved from 3966.60840 to 3953.45850, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 609s - loss: 3953.4585 - psnr: 13.2907 - total_variation: 102643.2734 - ssim_multiscale: 6.8030 - sharpdiff: 5.3363 - mean_absolute_error: 0.1183 - mean_squared_error: 0.0477 - val_loss: 6692.6636 - val_psnr: 11.7276 - val_total_variation: 22100.2109 - val_ssim_multiscale: 4.1124 - val_sharpdiff: 9.2485 - val_mean_absolute_error: 0.2016 - val_mean_squared_error: 0.0703
# Epoch 4/1000000
#
# Epoch 00004: loss improved from 3953.45850 to 3925.65796, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 611s - loss: 3925.6580 - psnr: 13.3104 - total_variation: 102592.3906 - ssim_multiscale: 6.8108 - sharpdiff: 5.3431 - mean_absolute_error: 0.1170 - mean_squared_error: 0.0475 - val_loss: 6505.2417 - val_psnr: 11.9113 - val_total_variation: 19498.3770 - val_ssim_multiscale: 4.2165 - val_sharpdiff: 9.4876 - val_mean_absolute_error: 0.1936 - val_mean_squared_error: 0.0680
# Epoch 5/1000000
#
# Epoch 00005: loss improved from 3925.65796 to 3887.73096, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 606s - loss: 3887.7310 - psnr: 13.3339 - total_variation: 102567.2500 - ssim_multiscale: 6.8271 - sharpdiff: 5.3512 - mean_absolute_error: 0.1155 - mean_squared_error: 0.0471 - val_loss: 7379.6626 - val_psnr: 11.3303 - val_total_variation: 20307.6230 - val_ssim_multiscale: 3.5919 - val_sharpdiff: 9.3265 - val_mean_absolute_error: 0.2163 - val_mean_squared_error: 0.0775
# Epoch 6/1000000
#
# Epoch 00006: loss improved from 3887.73096 to 3887.61694, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 604s - loss: 3887.6169 - psnr: 13.3416 - total_variation: 102498.4766 - ssim_multiscale: 6.8364 - sharpdiff: 5.3595 - mean_absolute_error: 0.1147 - mean_squared_error: 0.0472 - val_loss: 7589.9937 - val_psnr: 11.2133 - val_total_variation: 14409.8428 - val_ssim_multiscale: 3.5288 - val_sharpdiff: 9.8047 - val_mean_absolute_error: 0.2201 - val_mean_squared_error: 0.0806
# Epoch 7/1000000
#
# Epoch 00007: loss improved from 3887.61694 to 3864.26880, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 609s - loss: 3864.2688 - psnr: 13.3568 - total_variation: 102448.7891 - ssim_multiscale: 6.8428 - sharpdiff: 5.3656 - mean_absolute_error: 0.1137 - mean_squared_error: 0.0469 - val_loss: 8091.3745 - val_psnr: 11.1222 - val_total_variation: 15077.7266 - val_ssim_multiscale: 3.4211 - val_sharpdiff: 9.7537 - val_mean_absolute_error: 0.2100 - val_mean_squared_error: 0.0840
# Epoch 8/1000000
#
# Epoch 00008: loss improved from 3864.26880 to 3850.46997, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 603s - loss: 3850.4700 - psnr: 13.3668 - total_variation: 102411.9609 - ssim_multiscale: 6.8520 - sharpdiff: 5.3719 - mean_absolute_error: 0.1128 - mean_squared_error: 0.0468 - val_loss: 7376.1567 - val_psnr: 11.4068 - val_total_variation: 12179.6924 - val_ssim_multiscale: 3.9488 - val_sharpdiff: 10.0867 - val_mean_absolute_error: 0.2009 - val_mean_squared_error: 0.0796
# Epoch 9/1000000
#
# Epoch 00009: loss did not improve from 3850.46997
# 5000/5000 - 598s - loss: 3852.6785 - psnr: 13.3713 - total_variation: 102351.0938 - ssim_multiscale: 6.8563 - sharpdiff: 5.3773 - mean_absolute_error: 0.1124 - mean_squared_error: 0.0468 - val_loss: 7703.9404 - val_psnr: 11.1586 - val_total_variation: 10285.0693 - val_ssim_multiscale: 3.6750 - val_sharpdiff: 10.1966 - val_mean_absolute_error: 0.2102 - val_mean_squared_error: 0.0843
# Epoch 10/1000000
#
# Epoch 00010: loss improved from 3850.46997 to 3830.69067, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 601s - loss: 3830.6907 - psnr: 13.3804 - total_variation: 102317.8750 - ssim_multiscale: 6.8609 - sharpdiff: 5.3806 - mean_absolute_error: 0.1117 - mean_squared_error: 0.0467 - val_loss: 7407.7173 - val_psnr: 11.3200 - val_total_variation: 11536.7793 - val_ssim_multiscale: 3.8699 - val_sharpdiff: 10.1069 - val_mean_absolute_error: 0.2055 - val_mean_squared_error: 0.0807
# Epoch 11/1000000
#
# Epoch 00011: loss did not improve from 3830.69067
# 5000/5000 - 603s - loss: 3834.1165 - psnr: 13.3830 - total_variation: 102271.2656 - ssim_multiscale: 6.8646 - sharpdiff: 5.3851 - mean_absolute_error: 0.1114 - mean_squared_error: 0.0467 - val_loss: 7603.3765 - val_psnr: 11.1534 - val_total_variation: 11379.4229 - val_ssim_multiscale: 3.6483 - val_sharpdiff: 10.0877 - val_mean_absolute_error: 0.2137 - val_mean_squared_error: 0.0836
# Epoch 12/1000000
#
# Epoch 00012: loss improved from 3830.69067 to 3817.16919, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 617s - loss: 3817.1692 - psnr: 13.3906 - total_variation: 102263.1562 - ssim_multiscale: 6.8664 - sharpdiff: 5.3883 - mean_absolute_error: 0.1108 - mean_squared_error: 0.0465 - val_loss: 7977.8276 - val_psnr: 10.9755 - val_total_variation: 9654.4629 - val_ssim_multiscale: 3.5759 - val_sharpdiff: 10.2382 - val_mean_absolute_error: 0.2146 - val_mean_squared_error: 0.0882
# Epoch 00012: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:18:09, 27.07s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 1it [00:27, 27.06s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 2it [00:53, 26.97s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 3it [01:20, 26.96s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 4it [01:47, 26.86s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 5it [02:14, 26.83s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 6it [02:40, 26.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 7it [03:07, 26.73s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 8it [03:33, 26.64s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 9it [04:00, 26.70s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 10it [04:26, 26.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 11it [04:54, 26.76s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 12it [05:20, 26.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 13it [05:46, 26.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 14it [06:13, 26.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 15it [06:40, 26.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 16it [07:07, 26.74s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 17it [07:34, 26.81s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 18it [08:01, 26.83s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 19it [08:27, 26.76s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 20it [08:54, 26.79s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 21it [09:21, 26.76s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 22it [09:48, 26.89s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 23it [10:15, 26.94s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 24it [10:42, 27.02s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 25it [11:10, 27.11s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 26it [11:37, 27.25s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 27it [12:05, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 28it [12:33, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 29it [13:00, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 30it [13:28, 27.62s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 31it [13:56, 27.73s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 32it [14:24, 27.83s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 33it [14:52, 27.92s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 34it [15:21, 28.04s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 35it [15:49, 28.09s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
#
43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 273it [2:05:08, 26.37s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 274it [2:05:35, 26.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 275it [2:06:01, 26.38s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 276it [2:06:28, 26.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 277it [2:06:54, 26.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 278it [2:07:20, 26.38s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 279it [2:07:47, 26.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 280it [2:08:13, 26.33s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 281it [2:08:39, 26.37s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 282it [2:09:06, 26.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 283it [2:09:32, 26.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 284it [2:09:58, 26.36s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 285it [2:10:25, 26.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 286it [2:10:51, 26.35s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 287it [2:11:18, 26.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 288it [2:11:44, 26.38s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 289it [2:12:11, 26.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 290it [2:12:37, 26.36s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 291it [2:13:03, 26.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 292it [2:13:30, 26.34s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 293it [2:13:56, 26.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 294it [2:14:23, 26.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 295it [2:14:49, 26.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 296it [2:15:16, 26.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 297it [2:15:42, 26.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 298it [2:16:08, 26.42s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 299it [2:16:35, 26.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 300it [2:17:01, 26.43s/it]
# inception_score mean: [5.71726667e+157], sigma: inf

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 300it [04:24,  1.13it/s]
# perceptual path length score: 5193.7294921875

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00248241s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00180984s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00187397s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00173426s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:03,  2.60it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:04,  2.29it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:04,  2.23it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:04,  2.14it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:07,  4.28it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 131.89it/s]
# 10it [00:00, 143.70it/s]
# 0it [00:00, ?it/s]
# 10it [00:00, 132.60it/s]
# 10it [00:00, 138.24it/s]
# 100%|██████████| 4/4 [00:00<00:00, 11.49it/s]
# 10it [00:00, 129.97it/s]
