# %% [markdown]
# **Trained and tested except Frechet**

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 15891, done.
# remote: Total 15891 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15891/15891), 733.46 MiB | 45.86 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1697/1697), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
_instance_scale=1.0
for data in val_generator:
    print(data['images'].numpy().max())
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
latents_dim
# Out:
# 100

# %%
enc_lays = [tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),
            tf.keras.layers.Dense(units= latents_dim*intermediate_dim//3 , activation='relu'),

            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'AE_Dense_reconst_psnr_inverse'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse

# %%
from training.autoencoding_basic.autoencoders.autoencoder import autoencoder as AE

# %%
variables_params = \
[
    {
        'name': 'inference', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': enc_lays
    }

    ,
    
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   ERROR    | Faild to restore old models !
#   ERROR    | Faild to restore old models !
#   WARNING  | None
#   WARNING  | None
# SavedModel file does not exist at: /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir/pokemonAE_Dense_reconst_psnr_inverse_inference.hdf5/{saved_model.pbtxt|saved_model.pb}
#
#
# Model: "inference"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 50)      200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 50)      2550
# _________________________________________________________________
# flatten (Flatten)            (None, 500000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               50000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_outputs (Activatio (None, 100)               0
# =================================================================
# Total params: 50,003,250
# Trainable params: 50,003,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1666)              168266
# _________________________________________________________________
# dense_5 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_6 (Dense)              (None, 1666)              2777222
# _________________________________________________________________
# dense_7 (Dense)              (None, 30000)             50010000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 55,742,822
# Trainable params: 55,742,816
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.peak_signal_to_noise_ratio import prepare_psnr
#from statistical.losses_utilities import similarty_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
def similarity_to_distance(similarity_fn):
    distance_fn = lambda x, y: 0.5*(1-similarity_fn(x,y))
    return distance_fn

psnr = similarity_to_distance(prepare_psnr([ae.batch_size]+ae.get_inputs_shape()))

# %%
#ae.compile(metrics=None)
#ae.compile()
ae.compile(loss={'x_logits': lambda x_true, x_logits: psnr(x_true, x_logits)})
# Out:
# Model: "pokemonAE_Dense_reconst_psnr_inverse"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_inputs (InputLayer [(None, 100, 100, 3)]     0
# _________________________________________________________________
# inference (Functional)       (None, 100)               50003250
# _________________________________________________________________
# generative (Functional)      (None, 100, 100, 3)       55742822
# _________________________________________________________________
# tf_op_layer_x_logits (Tensor [(None, 100, 100, 3)]     0
# =================================================================
# Total params: 105,746,072
# Trainable params: 105,745,866
# Non-trainable params: 206
# _________________________________________________________________
# None

# %%
ae.output_shape
# Out:
# (None, 100, 100, 3)

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-15, 
    patience=10, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/csv_dir/pokemonAE_Dense_reconst_psnr_inverse.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %%
import numpy as np

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=val_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to -5.03920, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 595s - loss: -5.0392e+00 - psnr: 11.3339 - total_variation: 81215.8516 - ssim_multiscale: 4.5438 - sharpdiff: 5.7175 - mean_absolute_error: 0.2181 - mean_squared_error: 0.0785 - val_loss: -5.2454e+00 - val_psnr: 11.6555 - val_total_variation: 19998.8359 - val_ssim_multiscale: 3.6139 - val_sharpdiff: 9.3242 - val_mean_absolute_error: 0.2278 - val_mean_squared_error: 0.0713
# Epoch 2/1000000
#
# Epoch 00002: loss improved from -5.03920 to -5.80876, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 596s - loss: -5.8088e+00 - psnr: 12.9957 - total_variation: 95166.8828 - ssim_multiscale: 6.4024 - sharpdiff: 5.5625 - mean_absolute_error: 0.1494 - mean_squared_error: 0.0510 - val_loss: -5.1621e+00 - val_psnr: 11.4692 - val_total_variation: 16643.2871 - val_ssim_multiscale: 3.5557 - val_sharpdiff: 9.5783 - val_mean_absolute_error: 0.2355 - val_mean_squared_error: 0.0743
# Epoch 3/1000000
#
# Epoch 00003: loss improved from -5.80876 to -5.86180, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 593s - loss: -5.8618e+00 - psnr: 13.1043 - total_variation: 94545.4609 - ssim_multiscale: 6.5377 - sharpdiff: 5.6393 - mean_absolute_error: 0.1441 - mean_squared_error: 0.0498 - val_loss: -5.0842e+00 - val_psnr: 11.2997 - val_total_variation: 15628.9629 - val_ssim_multiscale: 3.5516 - val_sharpdiff: 9.6513 - val_mean_absolute_error: 0.2410 - val_mean_squared_error: 0.0763
# Epoch 4/1000000
#
# Epoch 00004: loss improved from -5.86180 to -5.88438, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 593s - loss: -5.8844e+00 - psnr: 13.1495 - total_variation: 94240.6875 - ssim_multiscale: 6.5788 - sharpdiff: 5.6712 - mean_absolute_error: 0.1418 - mean_squared_error: 0.0493 - val_loss: -5.1452e+00 - val_psnr: 11.4280 - val_total_variation: 15528.6162 - val_ssim_multiscale: 3.6459 - val_sharpdiff: 9.6909 - val_mean_absolute_error: 0.2365 - val_mean_squared_error: 0.0741
# Epoch 5/1000000
#
# Epoch 00005: loss improved from -5.88438 to -5.90090, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 592s - loss: -5.9009e+00 - psnr: 13.1812 - total_variation: 94106.6016 - ssim_multiscale: 6.6047 - sharpdiff: 5.6898 - mean_absolute_error: 0.1402 - mean_squared_error: 0.0488 - val_loss: -5.3497e+00 - val_psnr: 11.8706 - val_total_variation: 16436.8906 - val_ssim_multiscale: 3.9253 - val_sharpdiff: 9.6537 - val_mean_absolute_error: 0.2185 - val_mean_squared_error: 0.0672
# Epoch 6/1000000
#
# Epoch 00006: loss improved from -5.90090 to -5.91169, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 602s - loss: -5.9117e+00 - psnr: 13.1992 - total_variation: 94008.5078 - ssim_multiscale: 6.6234 - sharpdiff: 5.7037 - mean_absolute_error: 0.1392 - mean_squared_error: 0.0487 - val_loss: -5.4291e+00 - val_psnr: 12.0486 - val_total_variation: 17442.4473 - val_ssim_multiscale: 4.1115 - val_sharpdiff: 9.6108 - val_mean_absolute_error: 0.2101 - val_mean_squared_error: 0.0646
# Epoch 7/1000000
#
# Epoch 00007: loss improved from -5.91169 to -5.92210, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 602s - loss: -5.9221e+00 - psnr: 13.2177 - total_variation: 93962.2812 - ssim_multiscale: 6.6355 - sharpdiff: 5.7132 - mean_absolute_error: 0.1382 - mean_squared_error: 0.0484 - val_loss: -5.4213e+00 - val_psnr: 12.0386 - val_total_variation: 17865.6953 - val_ssim_multiscale: 4.1337 - val_sharpdiff: 9.5739 - val_mean_absolute_error: 0.2086 - val_mean_squared_error: 0.0647
# Epoch 8/1000000
#
# Epoch 00008: loss improved from -5.92210 to -5.92946, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 602s - loss: -5.9295e+00 - psnr: 13.2312 - total_variation: 93865.1250 - ssim_multiscale: 6.6441 - sharpdiff: 5.7227 - mean_absolute_error: 0.1374 - mean_squared_error: 0.0483 - val_loss: -5.4690e+00 - val_psnr: 12.1699 - val_total_variation: 17479.0391 - val_ssim_multiscale: 4.1914 - val_sharpdiff: 9.6174 - val_mean_absolute_error: 0.2007 - val_mean_squared_error: 0.0632
# Epoch 9/1000000
#
# Epoch 00009: loss improved from -5.92946 to -5.93055, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 603s - loss: -5.9305e+00 - psnr: 13.2329 - total_variation: 93820.4219 - ssim_multiscale: 6.6487 - sharpdiff: 5.7282 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0483 - val_loss: -5.4347e+00 - val_psnr: 12.0958 - val_total_variation: 18106.3672 - val_ssim_multiscale: 4.2059 - val_sharpdiff: 9.5671 - val_mean_absolute_error: 0.2024 - val_mean_squared_error: 0.0641
# Epoch 10/1000000
#
# Epoch 00010: loss improved from -5.93055 to -5.93491, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 603s - loss: -5.9349e+00 - psnr: 13.2423 - total_variation: 93779.9062 - ssim_multiscale: 6.6536 - sharpdiff: 5.7327 - mean_absolute_error: 0.1367 - mean_squared_error: 0.0482 - val_loss: -5.3489e+00 - val_psnr: 11.9045 - val_total_variation: 17806.3848 - val_ssim_multiscale: 4.1108 - val_sharpdiff: 9.5774 - val_mean_absolute_error: 0.2109 - val_mean_squared_error: 0.0671
# Epoch 11/1000000
#
# Epoch 00011: loss improved from -5.93491 to -5.93670, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 603s - loss: -5.9367e+00 - psnr: 13.2458 - total_variation: 93718.8359 - ssim_multiscale: 6.6574 - sharpdiff: 5.7378 - mean_absolute_error: 0.1364 - mean_squared_error: 0.0481 - val_loss: -5.3960e+00 - val_psnr: 12.0304 - val_total_variation: 16822.2168 - val_ssim_multiscale: 4.0925 - val_sharpdiff: 9.6546 - val_mean_absolute_error: 0.2054 - val_mean_squared_error: 0.0659
# Epoch 12/1000000
#
# Epoch 00012: loss improved from -5.93670 to -5.93806, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 603s - loss: -5.9381e+00 - psnr: 13.2497 - total_variation: 93721.9453 - ssim_multiscale: 6.6563 - sharpdiff: 5.7394 - mean_absolute_error: 0.1362 - mean_squared_error: 0.0481 - val_loss: -5.2818e+00 - val_psnr: 11.7858 - val_total_variation: 18208.0098 - val_ssim_multiscale: 4.0967 - val_sharpdiff: 9.5342 - val_mean_absolute_error: 0.2111 - val_mean_squared_error: 0.0689
# Epoch 13/1000000
#
# Epoch 00013: loss did not improve from -5.93806
# 5000/5000 - 601s - loss: -5.9378e+00 - psnr: 13.2496 - total_variation: 93679.8984 - ssim_multiscale: 6.6586 - sharpdiff: 5.7409 - mean_absolute_error: 0.1361 - mean_squared_error: 0.0481 - val_loss: -5.3809e+00 - val_psnr: 12.0016 - val_total_variation: 17277.6309 - val_ssim_multiscale: 4.1441 - val_sharpdiff: 9.6107 - val_mean_absolute_error: 0.2047 - val_mean_squared_error: 0.0660
# Epoch 14/1000000
#
# Epoch 00014: loss improved from -5.93806 to -5.93981, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 603s - loss: -5.9398e+00 - psnr: 13.2534 - total_variation: 93655.7109 - ssim_multiscale: 6.6627 - sharpdiff: 5.7438 - mean_absolute_error: 0.1358 - mean_squared_error: 0.0480 - val_loss: -5.1950e+00 - val_psnr: 11.5928 - val_total_variation: 18360.4570 - val_ssim_multiscale: 3.9961 - val_sharpdiff: 9.4905 - val_mean_absolute_error: 0.2187 - val_mean_squared_error: 0.0723
# Epoch 15/1000000
#
# Epoch 00015: loss did not improve from -5.93981
# 5000/5000 - 600s - loss: -5.9396e+00 - psnr: 13.2535 - total_variation: 93635.1016 - ssim_multiscale: 6.6592 - sharpdiff: 5.7451 - mean_absolute_error: 0.1357 - mean_squared_error: 0.0481 - val_loss: -5.3452e+00 - val_psnr: 11.9256 - val_total_variation: 17796.4902 - val_ssim_multiscale: 4.1227 - val_sharpdiff: 9.5570 - val_mean_absolute_error: 0.2073 - val_mean_squared_error: 0.0672
# Epoch 16/1000000
#
# Epoch 00016: loss did not improve from -5.93981
# 5000/5000 - 600s - loss: -5.9385e+00 - psnr: 13.2516 - total_variation: 93631.8359 - ssim_multiscale: 6.6592 - sharpdiff: 5.7442 - mean_absolute_error: 0.1358 - mean_squared_error: 0.0481 - val_loss: -5.3214e+00 - val_psnr: 12.0218 - val_total_variation: 18256.2695 - val_ssim_multiscale: 4.2060 - val_sharpdiff: 9.5440 - val_mean_absolute_error: 0.1960 - val_mean_squared_error: 0.0662
# Epoch 17/1000000
#
# Epoch 00017: loss improved from -5.93981 to -5.94285, saving model to /content/drive/My Drive/Results/pokemonAE_Dense_reconst_psnr_inverse/var_save_dir
# 5000/5000 - 601s - loss: -5.9428e+00 - psnr: 13.2607 - total_variation: 93609.7734 - ssim_multiscale: 6.6634 - sharpdiff: 5.7478 - mean_absolute_error: 0.1353 - mean_squared_error: 0.0479 - val_loss: -4.2706e+00 - val_psnr: 10.2920 - val_total_variation: 25388.8066 - val_ssim_multiscale: 3.8563 - val_sharpdiff: 8.9665 - val_mean_absolute_error: 0.2140 - val_mean_squared_error: 0.0960
# Epoch 18/1000000
#
# Epoch 00018: loss did not improve from -5.94285
# 5000/5000 - 597s - loss: -5.9392e+00 - psnr: 13.2536 - total_variation: 93590.2031 - ssim_multiscale: 6.6597 - sharpdiff: 5.7470 - mean_absolute_error: 0.1356 - mean_squared_error: 0.0481 - val_loss: -5.1761e+00 - val_psnr: 11.6233 - val_total_variation: 19170.2969 - val_ssim_multiscale: 3.9490 - val_sharpdiff: 9.4545 - val_mean_absolute_error: 0.2126 - val_mean_squared_error: 0.0717
# Epoch 00018: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:17:10, 27.36s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 1it [00:27, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 2it [00:54, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 3it [01:22, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 4it [01:49, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 5it [02:17, 27.61s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 6it [02:45, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 7it [03:12, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 8it [03:39, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 9it [04:07, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 10it [04:35, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 11it [05:02, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 12it [05:29, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 13it [05:57, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 14it [06:24, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 15it [06:52, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 16it [07:19, 27.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 17it [07:46, 27.42s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 18it [08:14, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 19it [08:41, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 20it [09:09, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 21it [09:36, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 22it [10:04, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 23it [10:31, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 24it [10:59, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 25it [11:26, 27.38s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 26it [11:53, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 27it [12:21, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 28it [12:48, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 29it [13:16, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 30it [13:43, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 31it [14:11, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 32it [14:38, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 33it [15:06, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 34it [15:33, 27.36s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 35it [16:00, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 36it [16:27, 27.25s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 37it [16:55, 27.35s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 38it [17:22, 27.25s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 39it [17:50, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 40it [18:17, 27.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 41it [18:44, 27.36s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 42it [19:12, 27.42s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 43it [19:39, 27.37s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 44it [20:06, 27.37s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 45it [20:33, 27.26s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 46it [21:01, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 47it [21:29, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 48it [21:56, 27.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 49it [22:23, 27.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 50it [22:51, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 51it [23:19, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 52it [23:46, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 53it [24:14, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 54it [24:41, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 55it [25:09, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 56it [25:36, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 57it [26:03, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 58it [26:31, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 59it [26:58, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 60it [27:26, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 61it [27:53, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 62it [28:21, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 63it [28:48, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 64it [29:15, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 65it [29:43, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 66it [30:10, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 67it [30:38, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 68it [31:05, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 69it [31:33, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 70it [32:00, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 71it [32:27, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 72it [32:55, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 73it [33:23, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 74it [33:50, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 75it [34:17, 27.34s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 76it [34:45, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 77it [35:12, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 78it [35:39, 27.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 79it [36:07, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 80it [36:35, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 81it [37:02, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 82it [37:30, 27.62s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 83it [37:58, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 84it [38:25, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 85it [38:53, 27.64s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 86it [39:20, 27.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 87it [39:48, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 88it [40:15, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 89it [40:43, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 90it [41:10, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 91it [41:38, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 92it [42:05, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 93it [42:33, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 94it [43:00, 27.61s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 95it [43:28, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 96it [43:56, 27.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 97it [44:24, 27.65s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 98it [44:51, 27.66s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 99it [45:18, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 100it [45:46, 27.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 101it [46:13, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 102it [46:41, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 103it [47:08, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 104it [47:36, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 105it [48:03, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 106it [48:31, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 107it [48:58, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 108it [49:26, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 109it [49:53, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 110it [50:20, 27.38s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 111it [50:48, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 112it [51:15, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 113it [51:43, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 114it [52:10, 27.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 115it [52:38, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 116it [53:05, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 117it [53:33, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 118it [54:01, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 119it [54:29, 27.69s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 120it [54:56, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 121it [55:24, 27.67s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 122it [55:51, 27.65s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 123it [56:19, 27.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 124it [56:47, 27.67s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 125it [57:14, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 126it [57:42, 27.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 127it [58:09, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 128it [58:37, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 129it [59:04, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 130it [59:33, 27.80s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 131it [1:00:01, 27.93s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 132it [1:00:28, 27.79s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 133it [1:00:56, 27.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 134it [1:01:24, 27.80s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 135it [1:01:51, 27.68s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 136it [1:02:19, 27.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 137it [1:02:47, 27.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 138it [1:03:14, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 139it [1:03:42, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 140it [1:04:09, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 141it [1:04:37, 27.61s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 142it [1:05:04, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 143it [1:05:32, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 144it [1:05:59, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 145it [1:06:27, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 146it [1:06:54, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 147it [1:07:21, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 148it [1:07:49, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 149it [1:08:17, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 150it [1:08:44, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 151it [1:09:12, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 152it [1:09:40, 27.66s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 153it [1:10:07, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 154it [1:10:35, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 155it [1:11:02, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 156it [1:11:29, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 157it [1:11:57, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 158it [1:12:24, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 159it [1:12:51, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 160it [1:13:19, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 161it [1:13:46, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 162it [1:14:14, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 163it [1:14:42, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 164it [1:15:10, 27.66s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 165it [1:15:37, 27.66s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 166it [1:16:05, 27.67s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 167it [1:16:32, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 168it [1:17:00, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 169it [1:17:28, 27.72s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 170it [1:17:55, 27.62s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 171it [1:18:23, 27.66s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 172it [1:18:51, 27.66s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 173it [1:19:19, 27.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 174it [1:19:46, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 175it [1:20:14, 27.67s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 176it [1:20:41, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 177it [1:21:09, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 178it [1:21:36, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 179it [1:22:03, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 180it [1:22:31, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 181it [1:22:59, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 182it [1:23:26, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 183it [1:23:53, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 184it [1:24:21, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 185it [1:24:49, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 186it [1:25:16, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 187it [1:25:44, 27.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 188it [1:26:11, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 189it [1:26:39, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 190it [1:27:06, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 191it [1:27:34, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 192it [1:28:01, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 193it [1:28:29, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 194it [1:28:56, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 195it [1:29:24, 27.43s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 196it [1:29:51, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 197it [1:30:19, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 198it [1:30:46, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 199it [1:31:14, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 200it [1:31:41, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 201it [1:32:09, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 202it [1:32:37, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 203it [1:33:04, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 204it [1:33:32, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 205it [1:33:59, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 206it [1:34:26, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 207it [1:34:54, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 208it [1:35:21, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 209it [1:35:49, 27.65s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 210it [1:36:17, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 211it [1:36:44, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 212it [1:37:12, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 213it [1:37:39, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 214it [1:38:07, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 215it [1:38:34, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 216it [1:39:02, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 217it [1:39:29, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 218it [1:39:57, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 219it [1:40:24, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 220it [1:40:52, 27.61s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 221it [1:41:19, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 222it [1:41:47, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 223it [1:42:14, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 224it [1:42:42, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 225it [1:43:09, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 226it [1:43:37, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 227it [1:44:04, 27.47s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 228it [1:44:32, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 229it [1:44:59, 27.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 230it [1:45:27, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 231it [1:45:54, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 232it [1:46:22, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 233it [1:46:50, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 234it [1:47:17, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 235it [1:47:45, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 236it [1:48:12, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 237it [1:48:39, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 238it [1:49:07, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 239it [1:49:34, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 240it [1:50:01, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 241it [1:50:29, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 242it [1:50:56, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 243it [1:51:24, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 244it [1:51:52, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 245it [1:52:19, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 246it [1:52:47, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 247it [1:53:14, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 248it [1:53:42, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 249it [1:54:09, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 250it [1:54:37, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 251it [1:55:04, 27.45s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 252it [1:55:32, 27.61s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 253it [1:55:59, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 254it [1:56:27, 27.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 255it [1:56:55, 27.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 256it [1:57:22, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 257it [1:57:50, 27.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 258it [1:58:17, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 259it [1:58:45, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 260it [1:59:12, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 261it [1:59:40, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 262it [2:00:07, 27.39s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 263it [2:00:34, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 264it [2:01:02, 27.40s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 265it [2:01:30, 27.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 266it [2:01:57, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 267it [2:02:25, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 268it [2:02:52, 27.41s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 269it [2:03:19, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 270it [2:03:47, 27.42s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 271it [2:04:14, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 272it [2:04:42, 27.55s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 273it [2:05:09, 27.52s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 274it [2:05:37, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 275it [2:06:04, 27.44s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 276it [2:06:32, 27.56s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 277it [2:06:59, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 278it [2:07:27, 27.59s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 279it [2:07:54, 27.46s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 280it [2:08:22, 27.57s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 281it [2:08:50, 27.51s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 282it [2:09:17, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 283it [2:09:45, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 284it [2:10:13, 27.63s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 285it [2:10:40, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 286it [2:11:07, 27.48s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 287it [2:11:35, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 288it [2:12:03, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 289it [2:12:31, 27.64s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 290it [2:12:58, 27.53s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 291it [2:13:25, 27.50s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 292it [2:13:53, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 293it [2:14:20, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 294it [2:14:48, 27.49s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 295it [2:15:16, 27.62s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 296it [2:15:43, 27.54s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 297it [2:16:11, 27.58s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 298it [2:16:38, 27.60s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 299it [2:17:06, 27.71s/it]/usr/local/lib/python3.6/dist-packages/dask/array/core.py:3967: RuntimeWarning: invalid value encountered in double_scalars
#   result = function(*args, **kwargs)
# 300it [2:17:34, 27.63s/it]
# inception_score mean: [2.09925671e+220], sigma: inf

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 300it [04:33,  1.12it/s]
# perceptual path length score: 4934.37255859375

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00241899s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00198269s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00178409s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00234294s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 67.73it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 40.26it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 38.17it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 42.97it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 80.57it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 136.26it/s]
# 10it [00:00, 143.03it/s]
# 0it [00:00, ?it/s]
# 10it [00:00, 141.62it/s]
# 10it [00:00, 113.63it/s]
# 100%|██████████| 4/4 [00:00<00:00, 11.34it/s]
# 10it [00:00, 143.45it/s]
