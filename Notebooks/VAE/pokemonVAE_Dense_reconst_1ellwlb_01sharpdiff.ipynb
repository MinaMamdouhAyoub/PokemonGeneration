# %% [markdown]
# Done training

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 15895 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15895/15895), 733.46 MiB | 39.73 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1698/1698), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
import numpy as np
_instance_scale=1.0
for data in val_generator:
    print(np.max(data['images']))
    break
    #print(data.keys())

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
menc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

venc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'VAE_Dense_reconst_1ell_01sharpdiff'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff

# %%
from training.autoencoding_basic.autoencoders.VAE import VAE as AE

# %%
#inputs_shape=image_size

# %%
variables_params = \
[
    {
        'name': 'inference_mean', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': menc_lays
    },
    
    {
        'name': 'inference_logvariance', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': venc_lays
    },
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   WARNING  | None
#   WARNING  | None
# Model: "inference_mean"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_mean_inputs (Input [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten (Flatten)            (None, 250000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_mean_outputs (Acti (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "inference_logvariance"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_logvariance_inputs [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 250000)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100)               0
# _________________________________________________________________
# inference_logvariance_output (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_8 (Dense)              (None, 30000)             1530000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_2 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 1,545,162
# Trainable params: 1,545,156
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.sharp_difference import prepare_sharpdiff
from statistical.losses_utilities import similarity_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+ 0.1*similarity_to_distance(prepare_sharpdiff([ae.batch_size]+ae.get_inputs_shape()))(x_true, x_logits)})
# Out:
# Model: "pokemonVAE_Dense_reconst_1ell_01sharpdiff"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inference_logvariance_inputs (I [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# inference_logvariance (Function (None, 100)          25001250    inference_logvariance_inputs[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# inference_mean_inputs (InputLay [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(10, 100)]          0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# inference_mean (Functional)     (None, 100)          25001250    inference_mean_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_z_latents (TensorFl [(10, 100)]          0           tf_op_layer_Mul_1[0][0]
#                                                                  inference_mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 100)]        0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(10, 100)]          0           tf_op_layer_z_latents[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [(None, 100)]        0           inference_mean[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference ( [(10, 100)]          0           tf_op_layer_RealDiv[0][0]
#                                                                  tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(10, 100)]          0           tf_op_layer_SquaredDifference[0][
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 100)]        0           tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# generative (Functional)         (None, 100, 100, 3)  1545162     tf_op_layer_z_latents[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(10, 100)]          0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_x_logits (TensorFlo [(10, 100, 100, 3)]  0           generative[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_logpdf (TensorFlowO [(10, 100)]          0           tf_op_layer_Sub[0][0]
# ==================================================================================================
# Total params: 51,547,662
# Trainable params: 51,547,256
# Non-trainable params: 406
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=1e-12, 
    patience=12, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/csv_dir/pokemonVAE_Dense_reconst_1ell_01sharpdiff.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=train_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 7493.69873, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 -
saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 205s - loss: 5879.3945 - x_logits_loss: 5876.5806 - x_logpdf_loss: -1.3764e+00 - z_latents_loss: 2.7547 - val_loss: 2595.6067 - val_x_logits_loss: 2593.1182 - val_x_logpdf_loss: -1.3888e+00 - val_z_latents_loss: 2.6192
# Epoch 46/1000000
#
# Epoch 00046: loss did not improve from 5879.39453
# 5000/5000 - 203s - loss: 5883.5630 - x_logits_loss: 5880.7368 - x_logpdf_loss: -1.3749e+00 - z_latents_loss: 2.7432 - val_loss: 2628.8650 - val_x_logits_loss: 2626.4746 - val_x_logpdf_loss: -1.3814e+00 - val_z_latents_loss: 2.5389
# Epoch 47/1000000
#
# Epoch 00047: loss improved from 5879.39453 to 5873.23633, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 204s - loss: 5873.2363 - x_logits_loss: 5870.4106 - x_logpdf_loss: -1.3747e+00 - z_latents_loss: 2.7308 - val_loss: 2591.7922 - val_x_logits_loss: 2589.3115 - val_x_logpdf_loss: -1.3800e+00 - val_z_latents_loss: 2.5915
# Epoch 48/1000000
#
# Epoch 00048: loss did not improve from 5873.23633
# 5000/5000 - 203s - loss: 5877.8169 - x_logits_loss: 5874.9839 - x_logpdf_loss: -1.3743e+00 - z_latents_loss: 2.7174 - val_loss: 2602.7053 - val_x_logits_loss: 2600.2366 - val_x_logpdf_loss: -1.3801e+00 - val_z_latents_loss: 2.5648
# Epoch 49/1000000
#
# Epoch 00049: loss improved from 5873.23633 to 5871.14502, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 204s - loss: 5871.1450 - x_logits_loss: 5868.3066 - x_logpdf_loss: -1.3747e+00 - z_latents_loss: 2.7021 - val_loss: 2616.0879 - val_x_logits_loss: 2613.7036 - val_x_logpdf_loss: -1.3743e+00 - val_z_latents_loss: 2.5138
# Epoch 50/1000000
#
# Epoch 00050: loss improved from 5871.14502 to 5866.56299, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 204s - loss: 5866.5630 - x_logits_loss: 5863.7266 - x_logpdf_loss: -1.3751e+00 - z_latents_loss: 2.6937 - val_loss: 2596.0874 - val_x_logits_loss: 2593.6274 - val_x_logpdf_loss: -1.3822e+00 - val_z_latents_loss: 2.5255
# Epoch 51/1000000
#
# Epoch 00051: loss did not improve from 5866.56299
# 5000/5000 - 203s - loss: 5869.5142 - x_logits_loss: 5866.6709 - x_logpdf_loss: -1.3758e+00 - z_latents_loss: 2.6814 - val_loss: 2600.7432 - val_x_logits_loss: 2598.3057 - val_x_logpdf_loss: -1.3715e+00 - val_z_latents_loss: 2.5038
# Epoch 52/1000000
#
# Epoch 00052: loss improved from 5866.56299 to 5866.12109, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 203s - loss: 5866.1211 - x_logits_loss: 5863.2686 - x_logpdf_loss: -1.3756e+00 - z_latents_loss: 2.6714 - val_loss: 2605.2649 - val_x_logits_loss: 2602.7664 - val_x_logpdf_loss: -1.3741e+00 - val_z_latents_loss: 2.5318
# Epoch 53/1000000
#
# Epoch 00053: loss did not improve from 5866.12109
# 5000/5000 - 203s - loss: 5881.4189 - x_logits_loss: 5878.5630 - x_logpdf_loss: -1.3765e+00 - z_latents_loss: 2.6618 - val_loss: 2578.8352 - val_x_logits_loss: 2576.3525 - val_x_logpdf_loss: -1.3780e+00 - val_z_latents_loss: 2.5161
# Epoch 54/1000000
#
# Epoch 00054: loss improved from 5866.12109 to 5860.47314, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 -
# Epoch 71/1000000
#
# Epoch 00071: loss did not improve from 5846.78711
# 5000/5000 - 207s - loss: 5852.3052 - x_logits_loss: 5849.3652 - x_logpdf_loss: -1.3797e+00 - z_latents_loss: 2.5486 - val_loss: 2767.2319 - val_x_logits_loss: 2764.6292 - val_x_logpdf_loss: -1.3805e+00 - val_z_latents_loss: 2.4875
# Epoch 72/1000000
#
# Epoch 00072: loss improved from 5846.78711 to 5845.59814, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 211s - loss: 5845.5981 - x_logits_loss: 5842.6528 - x_logpdf_loss: -1.3827e+00 - z_latents_loss: 2.5469 - val_loss: 2616.3723 - val_x_logits_loss: 2613.8765 - val_x_logpdf_loss: -1.3808e+00 - val_z_latents_loss: 2.4076
# Epoch 73/1000000
#
# Epoch 00073: loss did not improve from 5845.59814
# 5000/5000 - 208s - loss: 5847.1943 - x_logits_loss: 5844.2285 - x_logpdf_loss: -1.3823e+00 - z_latents_loss: 2.5432 - val_loss: 2584.7410 - val_x_logits_loss: 2582.1270 - val_x_logpdf_loss: -1.3825e+00 - val_z_latents_loss: 2.4514
# Epoch 74/1000000
#
# Epoch 00074: loss did not improve from 5845.59814
# 5000/5000 - 205s - loss: 5848.2417 - x_logits_loss: 5845.2666 - x_logpdf_loss: -1.3814e+00 - z_latents_loss: 2.5378 - val_loss: 2605.9290 - val_x_logits_loss: 2603.4592 - val_x_logpdf_loss: -1.3806e+00 - val_z_latents_loss: 2.3630
# Epoch 75/1000000
#
# Epoch 00075: loss improved from 5845.59814 to 5843.34863, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 207s - loss: 5843.3486 - x_logits_loss: 5840.3789 - x_logpdf_loss: -1.3790e+00 - z_latents_loss: 2.5329 - val_loss: 2577.4177 - val_x_logits_loss: 2574.8755 - val_x_logpdf_loss: -1.3786e+00 - val_z_latents_loss: 2.3812
# Epoch 76/1000000
#
# Epoch 00076: loss did not improve from 5843.34863
# 5000/5000 - 205s - loss: 5849.0176 - x_logits_loss: 5846.0269 - x_logpdf_loss: -1.3780e+00 - z_latents_loss: 2.5286 - val_loss: 2605.7871 - val_x_logits_loss: 2603.0708 - val_x_logpdf_loss: -1.3789e+00 - val_z_latents_loss: 2.4655
# Epoch 77/1000000
#
# Epoch 00077: loss improved from 5843.34863 to 5841.40430, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_01sharpdiff/var_save_dir
# 5000/5000 - 205s - loss: 5841.4043 - x_logits_loss: 5838.4243 - x_logpdf_loss: -1.3806e+00 - z_latents_loss: 2.5310 - val_loss: 2591.2563 - val_x_logits_loss: 2588.7561 - val_x_logpdf_loss: -1.3820e+00 - val_z_latents_loss: 2.3537
# Epoch 78/1000000
#
# Epoch 00078: loss did not improve from 5841.40430
# 5000/5000 - 204s - loss: 5846.9292 - x_logits_loss: 5843.9253 - x_logpdf_loss: -1.3817e+00 - z_latents_loss: 2.5286 - val_loss: 2575.7363 - val_x_logits_loss: 2573.1040 - val_x_logpdf_loss: -1.3783e+00 - val_z_latents_loss: 2.3815
# Epoch 79/1000000
#
# Epoch 00079: loss did not improve from 5841.40430
# 5000/5000 - 204s - loss: 5845.1157 - x_logits_loss: 5842.1064 - x_logpdf_loss: -1.3786e+00 - z_latents_loss: 2.5230 - val_loss: 2637.2205 - val_x_logits_loss: 2634.5842 - val_x_logpdf_loss: -1.3796e+00 - val_z_latents_loss: 2.4795
# Epoch 80/1000000
#
# Epoch 00080: loss did not improve from 5841.40430
# 5000/5000 - 204s - loss: 5844.0303 - x_logits_loss: 5841.0024 - x_logpdf_loss: -1.3781e+00 - z_latents_loss: 2.5185 - val_loss: 2645.2742 - val_x_logits_loss: 2642.6960 - val_x_logpdf_loss: -1.3773e+00 - val_z_latents_loss: 2.4240
# Epoch 81/1000000
#
# Epoch 00081: loss did not improve from 5841.40430
# 5000/5000 - 205s - loss: 5845.3472 - x_logits_loss: 5842.3271 - x_logpdf_loss: -1.3773e+00 - z_latents_loss: 2.5140 - val_loss: 2603.4189 - val_x_logits_loss: 2600.5811 - val_x_logpdf_loss: -1.3767e+00 - val_z_latents_loss: 2.5145
# Epoch 82/1000000
#
# Epoch 00082: loss did not improve from 5841.40430
# 5000/5000 - 205s - loss: 5848.2949 - x_logits_loss: 5845.2729 - x_logpdf_loss: -1.3786e+00 - z_latents_loss: 2.5125 - val_loss: 2597.2590 - val_x_logits_loss: 2594.4866 - val_x_logpdf_loss: -1.3787e+00 - val_z_latents_loss: 2.4573
# Epoch 83/1000000
#
# Epoch 00083: loss did not improve from 5841.40430
# 5000/5000 - 206s - loss: 5842.6631 - x_logits_loss: 5839.6245 - x_logpdf_loss: -1.3794e+00 - z_latents_loss: 2.5130 - val_loss: 2643.3074 - val_x_logits_loss: 2640.0188 - val_x_logpdf_loss: -1.3796e+00 - val_z_latents_loss: 2.6802
# Epoch 84/1000000
#
# Epoch 00084: loss did not improve from 5841.40430
# 5000/5000 - 206s - loss: 5853.5503 - x_logits_loss: 5850.4985 - x_logpdf_loss: -1.3797e+00 - z_latents_loss: 2.5116 - val_loss: 2737.3818 - val_x_logits_loss: 2733.8806 - val_x_logpdf_loss: -1.3810e+00 - val_z_latents_loss: 2.8553
# Epoch 85/1000000
#
# Epoch 00085: loss did not improve from 5841.40430
# 5000/5000 - 206s - loss: 5868.9326 - x_logits_loss: 5865.8770 - x_logpdf_loss: -1.3823e+00 - z_latents_loss: 2.5140 - val_loss: 2854.0371 - val_x_logits_loss: 2850.6858 - val_x_logpdf_loss: -1.3826e+00 - val_z_latents_loss: 2.8672
# Epoch 86/1000000
#
# Epoch 00086: loss did not improve from 5841.40430
# 5000/5000 - 207s - loss: 5887.0137 - x_logits_loss: 5883.9541 - x_logpdf_loss: -1.3811e+00 - z_latents_loss: 2.5181 - val_loss: 2979.1487 - val_x_logits_loss: 2975.1318 - val_x_logpdf_loss: -1.3804e+00 - val_z_latents_loss: 3.0897
# Epoch 87/1000000
#
# Epoch 00087: loss did not improve from 5841.40430
# 5000/5000 - 203s - loss: 5943.2646 - x_logits_loss: 5940.2104 - x_logpdf_loss: -1.3788e+00 - z_latents_loss: 2.5214 - val_loss: 2759.9878 - val_x_logits_loss: 2757.0115 - val_x_logpdf_loss: -1.3770e+00 - val_z_latents_loss: 2.5647
# Epoch 88/1000000
#
# Epoch 00088: loss did not improve from 5841.40430
# 5000/5000 - 204s - loss: 5935.8325 - x_logits_loss: 5932.7778 - x_logpdf_loss: -1.3755e+00 - z_latents_loss: 2.5229 - val_loss: 2879.0054 - val_x_logits_loss: 2875.6763 - val_x_logpdf_loss: -1.3758e+00 - val_z_latents_loss: 2.8610
# Epoch 89/1000000
#
# Epoch 00089: loss did not improve from 5841.40430
# 5000/5000 - 205s - loss: 5949.3838 - x_logits_loss: 5946.3232 - x_logpdf_loss: -1.3746e+00 - z_latents_loss: 2.5213 - val_loss: 3024.7002 - val_x_logits_loss: 3021.4316 - val_x_logpdf_loss: -1.3749e+00 - val_z_latents_loss: 2.9365
# Epoch 00089: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [8:07:33, 97.82s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 139it [3:44:06, 96.78s/it]

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
