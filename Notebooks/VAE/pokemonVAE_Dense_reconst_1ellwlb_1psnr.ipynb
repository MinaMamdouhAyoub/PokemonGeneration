# %% [markdown]
# fully trained and tested except frechet

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 15891, done.
# remote: Total 15891 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15891/15891), 733.46 MiB | 42.05 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1697/1697), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
import numpy as np
_instance_scale=1.0
for data in val_generator:
    print(np.max(data['images']))
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
menc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

venc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'VAE_Dense_reconst_1ellwlb_1psnr'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr

# %%
from training.autoencoding_basic.autoencoders.VAE import VAE as AE

# %%
#inputs_shape=image_size

# %%
variables_params = \
[
    {
        'name': 'inference_mean', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': menc_lays
    },
    
    {
        'name': 'inference_logvariance', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': venc_lays
    },
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   WARNING  | None
#   WARNING  | None
# Model: "inference_mean"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_mean_inputs (Input [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense_24 (Dense)             (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_25 (Dense)             (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 250000)            0
# _________________________________________________________________
# dense_26 (Dense)             (None, 100)               25000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_mean_outputs (Acti (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "inference_logvariance"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_logvariance_inputs [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense_27 (Dense)             (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_28 (Dense)             (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 250000)            0
# _________________________________________________________________
# dense_29 (Dense)             (None, 100)               25000100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100)               0
# _________________________________________________________________
# inference_logvariance_output (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_30 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_31 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_32 (Dense)             (None, 30000)             1530000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_2 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 1,545,162
# Trainable params: 1,545,156
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.peak_signal_to_noise_ratio import prepare_psnr
from statistical.losses_utilities import similarity_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+similarity_to_distance(prepare_psnr([ae.batch_size]+ae.get_inputs_shape()))(x_true, x_logits)})
# Out:
# Model: "pokemonVAE_Dense_reconst_1ellwlb_1psnr"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inference_logvariance_inputs (I [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# inference_logvariance (Function (None, 100)          25001250    inference_logvariance_inputs[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# inference_mean_inputs (InputLay [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(10, 100)]          0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# inference_mean (Functional)     (None, 100)          25001250    inference_mean_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_z_latents (TensorFl [(10, 100)]          0           tf_op_layer_Mul_1[0][0]
#                                                                  inference_mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 100)]        0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(10, 100)]          0           tf_op_layer_z_latents[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [(None, 100)]        0           inference_mean[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference ( [(10, 100)]          0           tf_op_layer_RealDiv[0][0]
#                                                                  tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(10, 100)]          0           tf_op_layer_SquaredDifference[0][
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 100)]        0           tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# generative (Functional)         (None, 100, 100, 3)  1545162     tf_op_layer_z_latents[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(10, 100)]          0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_x_logits (TensorFlo [(10, 100, 100, 3)]  0           generative[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_logpdf (TensorFlowO [(10, 100)]          0           tf_op_layer_Sub[0][0]
# ==================================================================================================
# Total params: 51,547,662
# Trainable params: 51,547,256
# Non-trainable params: 406
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=1e-12, 
    patience=12, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/csv_dir/pokemonVAE_Dense_reconst_1ellwlb_1psnr.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=train_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 6313.19629, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 200s - loss: 6313.1963 - x_logits_loss: 6311.3579 - x_logpdf_loss: -1.2916e+00 - z_latents_loss: 2.7382 - val_loss: 3209.4521 - val_x_logits_loss: 3207.5789 - val_x_logpdf_loss: -1.3027e+00 - val_z_latents_loss: 2.8021
# Epoch 2/1000000
#
# Epoch 00002: loss improved from 6313.19629 to 6223.39600, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 201s - loss: 6223.3960 - x_logits_loss: 6221.3940 - x_logpdf_loss: -1.3236e+00 - z_latents_loss: 2.8703 - val_loss: 3024.9404 - val_x_logits_loss: 3022.9561 - val_x_logpdf_loss: -1.3402e+00 - val_z_latents_loss: 2.8836
# Epoch 3/1000000
#
# Epoch 00003: loss improved from 6223.39600 to 6170.68799, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 199s - loss: 6170.6880 - x_logits_loss: 6168.6074 - x_logpdf_loss: -1.3478e+00 - z_latents_loss: 2.9577 - val_loss: 3122.7983 - val_x_logits_loss: 3120.7961 - val_x_logpdf_loss: -1.3572e+00 - val_z_latents_loss: 2.9405
# Epoch 4/1000000
#
# Epoch 00004: loss improved from 6170.68799 to 6132.28271, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 199s - loss: 6132.2827 - x_logits_loss: 6130.1118 - x_logpdf_loss: -1.3636e+00 - z_latents_loss: 3.0227 - val_loss: 2973.0916 - val_x_logits_loss: 2971.1548 - val_x_logpdf_loss: -1.3710e+00 - val_z_latents_loss: 2.8882
# Epoch 5/1000000
#
# Epoch 00005: loss improved from 6132.28271 to 6113.41699, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 199s - loss: 6113.4170 - x_logits_loss: 6111.1665 - x_logpdf_loss: -1.3733e+00 - z_latents_loss: 3.0737 - val_loss: 2836.7310 - val_x_logits_loss: 2834.5911 - val_x_logpdf_loss: -1.3735e+00 - val_z_latents_loss: 2.9922
# Epoch 6/1000000
#
# Epoch 00006: loss improved from 6113.41699 to 6096.65137, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 196s - loss: 6096.6514 - x_logits_loss: 6094.3501 - x_logpdf_loss: -1.3788e+00 - z_latents_loss: 3.1132 - val_loss: 2824.8936 - val_x_logits_loss: 2822.8096 - val_x_logpdf_loss: -1.3884e+00 - val_z_latents_loss: 2.9812
# Epoch 7/1000000
#
# Epoch 00007: loss improved from 6096.65137 to 6073.56885, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 195s - loss: 6073.5688 - x_logits_loss: 6071.2139 - x_logpdf_loss: -1.3845e+00 - z_latents_loss: 3.1490 - val_loss: 2849.5466 - val_x_logits_loss: 2847.3975 - val_x_logpdf_loss: -1.3866e+00 - val_z_latents_loss: 3.0425
# Epoch 8/1000000
#
# Epoch 00008: loss improved from 6073.56885 to 6066.93652, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 194s - loss: 6066.9365 - x_logits_loss: 6064.5479 - x_logpdf_loss: -1.3880e+00 - z_latents_loss: 3.1754 - val_loss: 2775.9504 - val_x_logits_loss: 2773.7639 - val_x_logpdf_loss: -1.3845e+00 - val_z_latents_loss: 3.0155
# Epoch 9/1000000
#
# Epoch 00009: loss improved from 6066.93652 to 6048.04541, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 195s - loss: 6048.0454 - x_logits_loss: 6045.6167 - x_logpdf_loss: -1.3909e+00 - z_latents_loss: 3.1937 - val_loss: 2681.1208 - val_x_logits_loss: 2678.7856 - val_x_logpdf_loss: -1.3959e+00 - val_z_latents_loss: 3.0931
# Epoch 10/1000000
#
# Epoch 00010: loss improved from 6048.04541 to 6040.77637, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 196s - loss: 6040.7764 - x_logits_loss: 6038.3086 - x_logpdf_loss: -1.3944e+00 - z_latents_loss: 3.2106 - val_loss: 2818.9001 - val_x_logits_loss: 2816.6177 - val_x_logpdf_loss: -1.4004e+00 - val_z_latents_loss: 3.1325
# Epoch 11/1000000
#
# Epoch 00011: loss improved from 6040.77637 to 6026.57715, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 200s - loss: 6026.5771 - x_logits_loss: 6024.0928 - x_logpdf_loss: -1.3961e+00 - z_latents_loss: 3.2242 - val_loss: 2689.9338 - val_x_logits_loss: 2687.5188 - val_x_logpdf_loss: -1.3930e+00 - val_z_latents_loss: 3.1420
# Epoch 12/1000000
#
# Epoch 00012: loss improved from 6026.57715 to 6015.95605, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 200s - loss: 6015.9561 - x_logits_loss: 6013.4321 - x_logpdf_loss: -1.3983e+00 - z_latents_loss: 3.2309 - val_loss: 2711.7092 - val_x_logits_loss: 2709.3179 - val_x_logpdf_loss: -1.3950e+00 - val_z_latents_loss: 3.1491
# Epoch 13/1000000
#
# Epoch 00013: loss improved from 6015.95605 to 6001.65527, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 199s - loss: 6001.6553 - x_logits_loss: 5999.0918 - x_logpdf_loss: -1.3987e+00 - z_latents_loss: 3.2325 - val_loss: 2821.3931 - val_x_logits_loss: 2819.2522 - val_x_logpdf_loss: -1.3924e+00 - val_z_latents_loss: 2.9449
# Epoch 14/1000000
#
# Epoch 00014: loss improved from 6001.65527 to 6001.36523, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 198s - loss: 6001.3652 - x_logits_loss: 5998.7852 - x_logpdf_loss: -1.3981e+00 - z_latents_loss: 3.2348 - val_loss: 2789.5564 - val_x_logits_loss: 2787.3689 - val_x_logpdf_loss: -1.4027e+00 - val_z_latents_loss: 2.9840
# Epoch 15/1000000
#
# Epoch 00015: loss improved from 6001.36523 to 5990.63818, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 201s - loss: 5990.6382 - x_logits_loss: 5988.0391 - x_logpdf_loss: -1.3985e+00 - z_latents_loss: 3.2322 - val_loss: 2855.3237 - val_x_logits_loss: 2853.0630 - val_x_logpdf_loss: -1.3957e+00 - val_z_latents_loss: 3.0330
# Epoch 16/1000000
#
# Epoch 00016: loss improved from 5990.63818 to 5981.08936, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 200s - loss: 5981.0894 - x_logits_loss: 5978.4619 - x_logpdf_loss: -1.3996e+00 - z_latents_loss: 3.2237 - val_loss: 2704.2476 - val_x_logits_loss: 2701.9426 - val_x_logpdf_loss: -1.4020e+00 - val_z_latents_loss: 2.9834
# Epoch 17/1000000
#
# Epoch 00017: loss improved from 5981.08936 to 5968.58740, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 201s - loss: 5968.5874 - x_logits_loss: 5965.9482 - x_logpdf_loss: -1.4010e+00 - z_latents_loss: 3.2151 - val_loss: 2751.5942 - val_x_logits_loss: 2749.2512 - val_x_logpdf_loss: -1.4032e+00 - val_z_latents_loss: 3.0249
# Epoch 18/1000000
#
# Epoch 00018: loss did not improve from 5968.58740
# 5000/5000 - 197s - loss: 5971.6768 - x_logits_loss: 5969.0049 - x_logpdf_loss: -1.4025e+00 - z_latents_loss: 3.2059 - val_loss: 2752.6567 - val_x_logits_loss: 2750.3274 - val_x_logpdf_loss: -1.4050e+00 - val_z_latents_loss: 3.0005
# Epoch 19/1000000
#
# Epoch 00019: loss improved from 5968.58740 to 5960.77100, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 197s - loss: 5960.7710 - x_logits_loss: 5958.0991 - x_logpdf_loss: -1.4036e+00 - z_latents_loss: 3.1979 - val_loss: 2739.0369 - val_x_logits_loss: 2736.7200 - val_x_logpdf_loss: -1.4032e+00 - val_z_latents_loss: 2.9716
# Epoch 20/1000000
#
# Epoch 00020: loss improved from 5960.77100 to 5956.15186, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 195s - loss: 5956.1519 - x_logits_loss: 5953.4463 - x_logpdf_loss: -1.4041e+00 - z_latents_loss: 3.1823 - val_loss: 2713.1558 - val_x_logits_loss: 2710.7664 - val_x_logpdf_loss: -1.4033e+00 - val_z_latents_loss: 3.0141
# Epoch 21/1000000
#
# Epoch 00021: loss improved from 5956.15186 to 5947.84424, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 196s - loss: 5947.8442 - x_logits_loss: 5945.1167 - x_logpdf_loss: -1.4043e+00 - z_latents_loss: 3.1737 - val_loss: 2674.8560 - val_x_logits_loss: 2672.4473 - val_x_logpdf_loss: -1.4037e+00 - val_z_latents_loss: 2.9539
# Epoch 22/1000000
#
# Epoch 00022: loss improved from 5947.84424 to 5944.00586, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 198s - loss: 5944.0059 - x_logits_loss: 5941.2612 - x_logpdf_loss: -1.4052e+00 - z_latents_loss: 3.1595 - val_loss: 2718.2432 - val_x_logits_loss: 2715.8940 - val_x_logpdf_loss: -1.4059e+00 - val_z_latents_loss: 2.9157
# Epoch 23/1000000
#
# Epoch 00023: loss did not improve from 5944.00586
# 5000/5000 - 196s - loss: 5947.0332 - x_logits_loss: 5944.2783 - x_logpdf_loss: -1.4076e+00 - z_latents_loss: 3.1478 - val_loss: 2758.4316 - val_x_logits_loss: 2756.1487 - val_x_logpdf_loss: -1.4059e+00 - val_z_latents_loss: 2.8921
# Epoch 24/1000000
#
# Epoch 00024: loss improved from 5944.00586 to 5924.47852, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 197s - loss: 5924.4785 - x_logits_loss: 5921.7075 - x_logpdf_loss: -1.4079e+00 - z_latents_loss: 3.1319 - val_loss: 2749.5315 - val_x_logits_loss: 2747.1721 - val_x_logpdf_loss: -1.4080e+00 - val_z_latents_loss: 2.9478
# Epoch 25/1000000
#
# Epoch 00025: loss did not improve from 5924.47852
# 5000/5000 - 195s - loss: 5925.4355 - x_logits_loss: 5922.6543 - x_logpdf_loss: -1.4111e+00 - z_latents_loss: 3.1192 - val_loss: 2643.0305 - val_x_logits_loss: 2640.4900 - val_x_logpdf_loss: -1.4071e+00 - val_z_latents_loss: 2.9722
# Epoch 26/1000000
#
# Epoch 00026: loss improved from 5924.47852 to 5923.97656, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 197s - loss: 5923.9766 - x_logits_loss: 5921.1675 - x_logpdf_loss: -1.4084e+00 - z_latents_loss: 3.1034 - val_loss: 2715.2241 - val_x_logits_loss: 2712.8125 - val_x_logpdf_loss: -1.4056e+00 - val_z_latents_loss: 2.9185
# Epoch 27/1000000
#
# Epoch 00027: loss improved from 5923.97656 to 5923.83350, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 197s - loss: 5923.8335 - x_logits_loss: 5921.0195 - x_logpdf_loss: -1.4081e+00 - z_latents_loss: 3.0867 - val_loss: 2759.5481 - val_x_logits_loss: 2757.2380 - val_x_logpdf_loss: -1.4061e+00 - val_z_latents_loss: 2.8201
# Epoch 28/1000000
#
# Epoch 00028: loss improved from 5923.83350 to 5913.18018, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 197s - loss: 5913.1802 - x_logits_loss: 5910.3447 - x_logpdf_loss: -1.4099e+00 - z_latents_loss: 3.0731 - val_loss: 2633.4600 - val_x_logits_loss: 2630.8760 - val_x_logpdf_loss: -1.4090e+00 - val_z_latents_loss: 2.9026
# Epoch 29/1000000
#
# Epoch 00029: loss improved from 5913.18018 to 5910.70459, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 197s - loss: 5910.7046 - x_logits_loss: 5907.8750 - x_logpdf_loss: -1.4104e+00 - z_latents_loss: 3.0584 - val_loss: 2728.3416 - val_x_logits_loss: 2725.9734 - val_x_logpdf_loss: -1.4050e+00 - val_z_latents_loss: 2.8615
# Epoch 30/1000000
#
# Epoch 00030: loss did not improve from 5910.70459
# 5000/5000 - 196s - loss: 5915.1724 - x_logits_loss: 5912.3169 - x_logpdf_loss: -1.4117e+00 - z_latents_loss: 3.0448 - val_loss: 2669.8069 - val_x_logits_loss: 2667.3064 - val_x_logpdf_loss: -1.4153e+00 - val_z_latents_loss: 2.8661
# Epoch 31/1000000
#
# Epoch 00031: loss improved from 5910.70459 to 5901.43945, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 201s - loss: 5901.4395 - x_logits_loss: 5898.5723 - x_logpdf_loss: -1.4125e+00 - z_latents_loss: 3.0333 - val_loss: 2683.5588 - val_x_logits_loss: 2681.1152 - val_x_logpdf_loss: -1.4064e+00 - val_z_latents_loss: 2.8278
# Epoch 32/1000000
#
# Epoch 00032: loss improved from 5901.43945 to 5891.90674, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 201s - loss: 5891.9067 - x_logits_loss: 5889.0195 - x_logpdf_loss: -1.4129e+00 - z_latents_loss: 3.0181 - val_loss: 2661.5825 - val_x_logits_loss: 2658.9478 - val_x_logpdf_loss: -1.4136e+00 - val_z_latents_loss: 2.9325
# Epoch 33/1000000
#
# Epoch 00033: loss did not improve from 5891.90674
# 5000/5000 - 202s - loss: 5894.8071 - x_logits_loss: 5891.9111 - x_logpdf_loss: -1.4130e+00 - z_latents_loss: 3.0049 - val_loss: 2671.6763 - val_x_logits_loss: 2669.2651 - val_x_logpdf_loss: -1.4152e+00 - val_z_latents_loss: 2.7867
# Epoch 34/1000000
#
# Epoch 00034: loss did not improve from 5891.90674
# 5000/5000 - 203s - loss: 5903.6821 - x_logits_loss: 5900.7852 - x_logpdf_loss: -1.4130e+00 - z_latents_loss: 2.9926 - val_loss: 2613.3616 - val_x_logits_loss: 2610.7510 - val_x_logpdf_loss: -1.4103e+00 - val_z_latents_loss: 2.8408
# Epoch 35/1000000
#
# Epoch 00035: loss did not improve from 5891.90674
# 5000/5000 - 204s - loss: 5904.3052 - x_logits_loss: 5901.3818 - x_logpdf_loss: -1.4132e+00 - z_latents_loss: 2.9783 - val_loss: 2669.8042 - val_x_logits_loss: 2667.3684 - val_x_logpdf_loss: -1.4111e+00 - val_z_latents_loss: 2.7551
# Epoch 36/1000000
#
# Epoch 00036: loss improved from 5891.90674 to 5890.34375, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 209s - loss: 5890.3438 - x_logits_loss: 5887.4106 - x_logpdf_loss: -1.4113e+00 - z_latents_loss: 2.9643 - val_loss: 2606.6907 - val_x_logits_loss: 2603.9839 - val_x_logpdf_loss: -1.4112e+00 - val_z_latents_loss: 2.8606
# Epoch 37/1000000
#
# Epoch 00037: loss did not improve from 5890.34375
# 5000/5000 - 204s - loss: 5893.6763 - x_logits_loss: 5890.7368 - x_logpdf_loss: -1.4119e+00 - z_latents_loss: 2.9547 - val_loss: 2652.1140 - val_x_logits_loss: 2649.5801 - val_x_logpdf_loss: -1.4065e+00 - val_z_latents_loss: 2.7746
# Epoch 38/1000000
#
# Epoch 00038: loss did not improve from 5890.34375
# 5000/5000 - 204s - loss: 5893.6226 - x_logits_loss: 5890.6626 - x_logpdf_loss: -1.4118e+00 - z_latents_loss: 2.9445 - val_loss: 2799.9673 - val_x_logits_loss: 2797.5972 - val_x_logpdf_loss: -1.4137e+00 - val_z_latents_loss: 2.7390
# Epoch 39/1000000
#
# Epoch 00039: loss improved from 5890.34375 to 5889.85986, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 205s - loss: 5889.8599 - x_logits_loss: 5886.9019 - x_logpdf_loss: -1.4129e+00 - z_latents_loss: 2.9355 - val_loss: 2627.8215 - val_x_logits_loss: 2625.2698 - val_x_logpdf_loss: -1.4193e+00 - val_z_latents_loss: 2.7364
# Epoch 40/1000000
#
# Epoch 00040: loss improved from 5889.85986 to 5884.02246, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 206s - loss: 5884.0225 - x_logits_loss: 5881.0400 - x_logpdf_loss: -1.4134e+00 - z_latents_loss: 2.9249 - val_loss: 2632.5542 - val_x_logits_loss: 2630.0205 - val_x_logpdf_loss: -1.4147e+00 - val_z_latents_loss: 2.7216
# Epoch 41/1000000
#
# Epoch 00041: loss improved from 5884.02246 to 5883.16602, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 206s - loss: 5883.1660 - x_logits_loss: 5880.1704 - x_logpdf_loss: -1.4115e+00 - z_latents_loss: 2.9158 - val_loss: 2653.8579 - val_x_logits_loss: 2651.3921 - val_x_logpdf_loss: -1.4120e+00 - val_z_latents_loss: 2.6911
# Epoch 42/1000000
#
# Epoch 00042: loss did not improve from 5883.16602
# 5000/5000 - 204s - loss: 5883.3779 - x_logits_loss: 5880.3765 - x_logpdf_loss: -1.4107e+00 - z_latents_loss: 2.9009 - val_loss: 2719.9761 - val_x_logits_loss: 2717.5728 - val_x_logpdf_loss: -1.4113e+00 - val_z_latents_loss: 2.7095
# Epoch 43/1000000
#
# Epoch 00043: loss improved from 5883.16602 to 5875.66357, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 205s - loss: 5875.6636 - x_logits_loss: 5872.6475 - x_logpdf_loss: -1.4120e+00 - z_latents_loss: 2.8954 - val_loss: 2596.0317 - val_x_logits_loss: 2593.3525 - val_x_logpdf_loss: -1.4135e+00 - val_z_latents_loss: 2.7565
# Epoch 44/1000000
#
# Epoch 00044: loss did not improve from 5875.66357
# 5000/5000 - 205s - loss: 5877.7651 - x_logits_loss: 5874.7461 - x_logpdf_loss: -1.4135e+00 - z_latents_loss: 2.8824 - val_loss: 2613.3142 - val_x_logits_loss: 2610.4487 - val_x_logpdf_loss: -1.4096e+00 - val_z_latents_loss: 2.8001
# Epoch 45/1000000
#
# Epoch 00045: loss improved from 5875.66357 to 5874.60205, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_1psnr/var_save_dir
# 5000/5000 - 207s - loss: 5874.6021 - x_logits_loss: 5871.5640 - x_logpdf_loss: -1.4141e+00 - z_latents_loss: 2.8761 - val_loss: 3340.1816 - val_x_logits_loss: 3335.9844 - val_x_logpdf_loss: -1.4117e+00 - val_z_latents_loss: 3.4492
# Epoch 46/1000000
#
# Epoch 00046: loss did not improve from 5874.60205
# 5000/5000 - 205s - loss: 5881.6577 - x_logits_loss: 5878.6138 - x_logpdf_loss: -1.4133e+00 - z_latents_loss: 2.8618 - val_loss: 6772.5459 - val_x_logits_loss: 6763.0161 - val_x_logpdf_loss: -1.4108e+00 - val_z_latents_loss: 6.2834
# Epoch 47/1000000
#
# Epoch 00047: loss did not improve from 5874.60205
# 5000/5000 - 204s - loss: 5887.2998 - x_logits_loss: 5884.2500 - x_logpdf_loss: -1.4132e+00 - z_latents_loss: 2.8517 - val_loss: 5015.5620 - val_x_logits_loss: 5009.9917 - val_x_logpdf_loss: -1.4177e+00 - val_z_latents_loss: 4.1784
# Epoch 48/1000000
#
# Epoch 00048: loss did not improve from 5874.60205
# 5000/5000 - 203s - loss: 5894.5732 - x_logits_loss: 5891.5142 - x_logpdf_loss: -1.4126e+00 - z_latents_loss: 2.8431 - val_loss: 11909.4785 - val_x_logits_loss: 11896.3760 - val_x_logpdf_loss: -1.4066e+00 - val_z_latents_loss: 8.1291
# Epoch 49/1000000
#
# Epoch 00049: loss did not improve from 5874.60205
# 5000/5000 - 204s - loss: 5928.8735 - x_logits_loss: 5925.8101 - x_logpdf_loss: -1.4126e+00 - z_latents_loss: 2.8355 - val_loss: 2785.5378 - val_x_logits_loss: 2782.2068 - val_x_logpdf_loss: -1.4102e+00 - val_z_latents_loss: 3.1819
# Epoch 50/1000000
#
# Epoch 00050: loss did not improve from 5874.60205
# 5000/5000 - 204s - loss: 5908.1025 - x_logits_loss: 5905.0298 - x_logpdf_loss: -1.4113e+00 - z_latents_loss: 2.8270 - val_loss: 7294.3643 - val_x_logits_loss: 7286.0161 - val_x_logpdf_loss: -1.4148e+00 - val_z_latents_loss: 6.5914
# Epoch 51/1000000
#
# Epoch 00051: loss did not improve from 5874.60205
# 5000/5000 - 204s - loss: 5939.6650 - x_logits_loss: 5936.5938 - x_logpdf_loss: -1.4113e+00 - z_latents_loss: 2.8209 - val_loss: 3133.3049 - val_x_logits_loss: 3128.9045 - val_x_logpdf_loss: -1.4116e+00 - val_z_latents_loss: 3.8304
# Epoch 52/1000000
#
# Epoch 00052: loss did not improve from 5874.60205
# 5000/5000 - 204s - loss: 5976.4985 - x_logits_loss: 5973.4170 - x_logpdf_loss: -1.4098e+00 - z_latents_loss: 2.8169 - val_loss: 3065.6189 - val_x_logits_loss: 3061.6157 - val_x_logpdf_loss: -1.4082e+00 - val_z_latents_loss: 3.3529
# Epoch 53/1000000
#
# Epoch 00053: loss did not improve from 5874.60205
# 5000/5000 - 203s - loss: 5958.6484 - x_logits_loss: 5955.5659 - x_logpdf_loss: -1.4085e+00 - z_latents_loss: 2.8145 - val_loss: 3094.5850 - val_x_logits_loss: 3090.3154 - val_x_logpdf_loss: -1.4094e+00 - val_z_latents_loss: 3.6886
# Epoch 54/1000000
#
# Epoch 00054: loss did not improve from 5874.60205
# 5000/5000 - 203s - loss: 6042.0137 - x_logits_loss: 6038.9312 - x_logpdf_loss: -1.4115e+00 - z_latents_loss: 2.8184 - val_loss: 6797.9717 - val_x_logits_loss: 6788.3667 - val_x_logpdf_loss: -1.4080e+00 - val_z_latents_loss: 5.9223
# Epoch 55/1000000
#
# Epoch 00055: loss did not improve from 5874.60205
# 5000/5000 - 204s - loss: 6076.5439 - x_logits_loss: 6073.4565 - x_logpdf_loss: -1.4108e+00 - z_latents_loss: 2.8269 - val_loss: 3719.5447 - val_x_logits_loss: 3714.9421 - val_x_logpdf_loss: -1.4120e+00 - val_z_latents_loss: 3.9621
# Epoch 56/1000000
#
# Epoch 00056: loss did not improve from 5874.60205
# 5000/5000 - 204s - loss: 6159.2607 - x_logits_loss: 6156.1655 - x_logpdf_loss: -1.4097e+00 - z_latents_loss: 2.8281 - val_loss: 3639.9417 - val_x_logits_loss: 3635.5859 - val_x_logpdf_loss: -1.3987e+00 - val_z_latents_loss: 3.8153
# Epoch 57/1000000
#
# Epoch 00057: loss did not improve from 5874.60205
# 5000/5000 - 203s - loss: 6187.1426 - x_logits_loss: 6184.0645 - x_logpdf_loss: -1.4048e+00 - z_latents_loss: 2.8248 - val_loss: 3261.6768 - val_x_logits_loss: 3258.2637 - val_x_logpdf_loss: -1.4060e+00 - val_z_latents_loss: 3.0354
# Epoch 00057: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:22:38, 28.43s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 300it [2:22:55, 28.53s/it]
# inception_score mean: [8.87261991e+80], sigma: 4.675510050366724e+162

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 300it [04:53,  1.03s/it]
# perceptual path length score: 4625.68798828125

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00285316s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00225425s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00235319s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00229716s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:07,  1.26it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:07,  1.31it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:07,  1.34it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:07,  1.37it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:13,  2.36it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 3it [00:00, 26.03it/s]
# 10it [00:00, 25.27it/s]
# 3it [00:00, 24.63it/s]
# 10it [00:00, 25.17it/s]
# 3it [00:00, 25.11it/s]
# 10it [00:00, 25.44it/s]
# 3it [00:00, 24.36it/s]
# 10it [00:00, 23.51it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.32it/s]
# 10it [00:00, 26.00it/s]
