# %% [markdown]
# Full Training and testing Done

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 15895 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15895/15895), 733.46 MiB | 46.63 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1698/1698), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
import numpy as np
_instance_scale=1.0
for data in val_generator:
    print(np.max(data['images']))
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
menc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

venc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'VAE_Dense_reconst_1ellwlb_01ssim'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim

# %%
from training.autoencoding_basic.autoencoders.VAE import VAE as AE

# %%
#inputs_shape=image_size

# %%
variables_params = \
[
    {
        'name': 'inference_mean', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': menc_lays
    },
    
    {
        'name': 'inference_logvariance', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': venc_lays
    },
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   WARNING  | None
#   WARNING  | None
# Model: "inference_mean"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_mean_inputs (Input [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten (Flatten)            (None, 250000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_mean_outputs (Acti (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "inference_logvariance"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_logvariance_inputs [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 250000)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100)               0
# _________________________________________________________________
# inference_logvariance_output (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_8 (Dense)              (None, 30000)             1530000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_2 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 1,545,162
# Trainable params: 1,545,156
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.structural_similarity import prepare_ssim_multiscale
from statistical.losses_utilities import similarity_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+ 0.1*similarity_to_distance(prepare_ssim_multiscale([ae.batch_size]+ae.get_inputs_shape()))(x_true, x_logits)})
# Out:
# Model: "pokemonVAE_Dense_reconst_1ellwlb_01ssim"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inference_logvariance_inputs (I [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# inference_logvariance (Function (None, 100)          25001250    inference_logvariance_inputs[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# inference_mean_inputs (InputLay [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(10, 100)]          0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# inference_mean (Functional)     (None, 100)          25001250    inference_mean_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_z_latents (TensorFl [(10, 100)]          0           tf_op_layer_Mul_1[0][0]
#                                                                  inference_mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 100)]        0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(10, 100)]          0           tf_op_layer_z_latents[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [(None, 100)]        0           inference_mean[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference ( [(10, 100)]          0           tf_op_layer_RealDiv[0][0]
#                                                                  tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(10, 100)]          0           tf_op_layer_SquaredDifference[0][
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 100)]        0           tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# generative (Functional)         (None, 100, 100, 3)  1545162     tf_op_layer_z_latents[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(10, 100)]          0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_x_logits (TensorFlo [(10, 100, 100, 3)]  0           generative[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_logpdf (TensorFlowO [(10, 100)]          0           tf_op_layer_Sub[0][0]
# ==================================================================================================
# Total params: 51,547,662
# Trainable params: 51,547,256
# Non-trainable params: 406
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=1e-12, 
    patience=12, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/csv_dir/pokemonVAE_Dense_reconst_1ellwlb_01ssim.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=train_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py
saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir
# 5000/5000 - 254s - loss: 5947.8267 - x_logits_loss: 5945.2197 - x_logpdf_loss: -1.3848e+00 - z_latents_loss: 3.0418 - val_loss: 2654.5327 - val_x_logits_loss: 2652.1318 - val_x_logpdf_loss: -1.3589e+00 - val_z_latents_loss: 2.8703
# Epoch 26/1000000
#
# Epoch 00026: loss improved from 5947.82666 to 5946.85498, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir
# 5000/5000 - 254s - loss: 5946.8550 - x_logits_loss: 5944.2456 - x_logpdf_loss: -1.3856e+00 - z_latents_loss: 3.0323 - val_loss: 2690.6724 - val_x_logits_loss: 2688.2996 - val_x_logpdf_loss: -1.3454e+00 - val_z_latents_loss: 2.8765
# Epoch 27/1000000
#
# Epoch 00027: loss did not improve from 5946.85498
# 5000/5000 - 251s - loss: 5947.2529 - x_logits_loss: 5944.6318 - x_logpdf_loss: -1.3871e+00 - z_latents_loss: 3.0198 - val_loss: 2726.4023 - val_x_logits_loss: 2724.0269 - val_x_logpdf_loss: -1.3364e+00 - val_z_latents_loss: 2.8627
# Epoch 28/1000000
#
# Epoch 00028: loss improved from 5946.85498 to 5937.64307, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir
# 5000/5000 - 253s - loss: 5937.6431 - x_logits_loss: 5934.9790 - x_logpdf_loss: -1.3879e+00 - z_latents_loss: 3.0101 - val_loss: 2699.4565 - val_x_logits_loss: 2697.1462 - val_x_logpdf_loss: -1.3752e+00 - val_z_latents_loss: 2.8000
# Epoch 29/1000000
#
# Epoch 00029: loss improved from 5937.64307 to 5932.33350, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir
# 5000/5000 - 254s - loss: 5932.3335 - x_logits_loss: 5929.6504 - x_logpdf_loss: -1.3892e+00 - z_latents_loss: 3.0064 - val_loss: 2629.6631 - val_x_logits_loss: 2627.2542 - val_x_logpdf_loss: -1.3227e+00 - val_z_latents_loss: 2.7641
# Epoch 30/1000000
#
# Epoch 00030: loss did not improve from 5932.33350
# 5000/5000 - 252s - loss: 5936.4443 - x_logits_loss: 5933.7432 - x_logpdf_loss: -1.3901e+00 - z_latents_loss: 3.0016 - val_loss: 2786.7156 - val_x_logits_loss: 2784.1709 - val_x_logpdf_loss: -1.4371e+00 - val_z_latents_loss: 3.1098
# Epoch 31/1000000
#
# Epoch 00031: loss improved from 5932.33350 to 5922.19971, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir
# 5000/5000 - 254s - loss: 5922.1997 - x_logits_loss: 5919.4761 - x_logpdf_loss: -1.3935e+00 - z_latents_loss: 3.0002 - val_loss: 2660.2222 - val_x_logits_loss: 2657.8264 - val_x_logpdf_loss: -1.3950e+00 - val_z_latents_loss: 2.8459
# Epoch 32/1000000
#
# Epoch 00032: loss improved from 5922.19971 to 5910.03320, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir
# 5000/5000 - 254s - loss: 5910.0332 - x_logits_loss: 5907.3057 - x_logpdf_loss: -1.3946e+00 - z_latents_loss: 2.9936 - val_loss: 2781.3040 - val_x_logits_loss: 2778.8096 - val_x_logpdf_loss: -1.4094e+00 - val_z_latents_loss: 2.9450
# Epoch 33/1000000
#
# Epoch 00033: loss did not improve from 5910.03320
# 5000/5000 - 252s - loss: 5915.6689 - x_logits_loss: 5912.9180 - x_logpdf_loss: -1.3941e+00 - z_latents_loss: 2.9821 - val_loss: 2683.4907 - val_x_logits_loss: 2681.1252 - val_x_logpdf_loss: -1.3720e+00 - val_z_latents_loss: 2.7537
# Epoch 34/1000000
#
# Epoch 00034: loss did not improve from 5910.03320
# 5000/5000 - 252s - loss: 5924.3628 - x_logits_loss: 5921.6104 - x_logpdf_loss: -1.3933e+00 - z_latents_loss: 2.9709 - val_loss: 3402.3423 - val_x_logits_loss: 3399.3325 - val_x_logpdf_loss: -1.4032e+00 - val_z_latents_loss: 3.4994
# Epoch 35/1000000
#
# Epoch 00035: loss did not improve from 5910.03320
# 5000/5000 - 251s - loss: 5922.0283 - x_logits_loss: 5919.2578 - x_logpdf_loss: -1.3942e+00 - z_latents_loss: 2.9628 - val_loss: 2685.2915 - val_x_logits_loss: 2682.8787 - val_x_logpdf_loss: -1.3971e+00 - val_z_latents_loss: 2.8053
# Epoch 36/1000000
#
# Epoch 00036: loss improved from 5910.03320 to 5908.93359, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01ssim/var_save_dir
# 5000/5000 - 254s - loss: 5908.9336 - x_logits_loss: 5906.1318 - x_logpdf_loss: -1.3948e+00 - z_latents_loss: 2.9522 - val_loss: 2832.9648 - val_x_logits_loss: 2830.6577 - val_x_logpdf_loss: -1.3614e+00 - val_z_latents_loss: 2.7897
# Epoch 37/1000000
#
# Epoch 00037: loss did not improve from 5908.93359
# 5000/5000 - 251s - loss: 5917.7554 - x_logits_loss: 5914.9639 - x_logpdf_loss: -1.3922e+00 - z_latents_loss: 2.9397 - val_loss: 2711.4734 - val_x_logits_loss: 2709.1267 - val_x_logpdf_loss: -1.4074e+00 - val_z_latents_loss: 2.7677
# Epoch 38/1000000
#
# Epoch 00038: loss did not improve from 5908.93359
# 5000/5000 - 252s - loss: 5914.8237 - x_logits_loss: 5912.0200 - x_logpdf_loss: -1.3934e+00 - z_latents_loss: 2.9333 - val_loss: 2703.6653 - val_x_logits_loss: 2700.3428 - val_x_logpdf_loss: -1.4092e+00 - val_z_latents_loss: 3.2215
# Epoch 39/1000000
#
# Epoch 00039: loss did not improve from 5908.93359
# 5000/5000 - 252s - loss: 5912.7627 - x_logits_loss: 5909.9614 - x_logpdf_loss: -1.3925e+00 - z_latents_loss: 2.9200 - val_loss: 2635.3052 - val_x_logits_loss: 2632.8027 - val_x_logpdf_loss: -1.3950e+00 - val_z_latents_loss: 2.7567
# Epoch 40/1000000
#
# Epoch 00040: loss did not improve from 5908.93359
# 5000/5000 - 252s - loss: 5916.7007 - x_logits_loss: 5913.8887 - x_logpdf_loss: -1.3926e+00 - z_latents_loss: 2.9121 - val_loss: 3937.1953 - val_x_logits_loss: 3932.4302 - val_x_logpdf_loss: -1.3909e+00 - val_z_latents_loss: 4.1957
# Epoch 41/1000000
#
# Epoch 00041: loss did not improve from 5908.93359
# 5000/5000 - 252s - loss: 5923.5063 - x_logits_loss: 5920.6831 - x_logpdf_loss: -1.3926e+00 - z_latents_loss: 2.9045 - val_loss: 2680.5725 - val_x_logits_loss: 2677.8411 - val_x_logpdf_loss: -1.3917e+00 - val_z_latents_loss: 2.9015
# Epoch 42/1000000
#
# Epoch 00042: loss did not improve from 5908.93359
# 5000/5000 - 251s - loss: 5953.4731 - x_logits_loss: 5950.6196 - x_logpdf_loss: -1.3944e+00 - z_latents_loss: 2.8996 - val_loss: 3045.6326 - val_x_logits_loss: 3042.3359 - val_x_logpdf_loss: -1.3930e+00 - val_z_latents_loss: 3.4634
# Epoch 43/1000000
#
# Epoch 00043: loss did not improve from 5908.93359
# 5000/5000 - 251s - loss: 5941.0234 - x_logits_loss: 5938.1797 - x_logpdf_loss: -1.3942e+00 - z_latents_loss: 2.8913 - val_loss: 5189.1865 - val_x_logits_loss: 5182.4414 - val_x_logpdf_loss: -1.4007e+00 - val_z_latents_loss: 5.4940
# Epoch 44/1000000
#
# Epoch 00044: loss did not improve from 5908.93359
# 5000/5000 - 250s - loss: 5971.0776 - x_logits_loss: 5968.2251 - x_logpdf_loss: -1.3951e+00 - z_latents_loss: 2.8824 - val_loss: 4761.1963 - val_x_logits_loss: 4755.4536 - val_x_logpdf_loss: -1.3759e+00 - val_z_latents_loss: 5.7292
# Epoch 45/1000000
#
# Epoch 00045: loss did not improve from 5908.93359
# 5000/5000 - 250s - loss: 5974.5293 - x_logits_loss: 5971.6807 - x_logpdf_loss: -1.3962e+00 - z_latents_loss: 2.8778 - val_loss: 3026.5459 - val_x_logits_loss: 3023.2197 - val_x_logpdf_loss: -1.3879e+00 - val_z_latents_loss: 3.4170
# Epoch 46/1000000
#
# Epoch 00046: loss did not improve from 5908.93359
# 5000/5000 - 250s - loss: 5984.3896 - x_logits_loss: 5981.5610 - x_logpdf_loss: -1.3957e+00 - z_latents_loss: 2.8629 - val_loss: 3368.3782 - val_x_logits_loss: 3365.1484 - val_x_logpdf_loss: -1.3978e+00 - val_z_latents_loss: 3.4965
# Epoch 47/1000000
#
# Epoch 00047: loss did not improve from 5908.93359
# 5000/5000 - 249s - loss: 5992.9434 - x_logits_loss: 5990.0967 - x_logpdf_loss: -1.3941e+00 - z_latents_loss: 2.8491 - val_loss: 3903.0117 - val_x_logits_loss: 3898.5972 - val_x_logpdf_loss: -1.3890e+00 - val_z_latents_loss: 3.8524
# Epoch 48/1000000
#
# Epoch 00048: loss did not improve from 5908.93359
# 5000/5000 - 251s - loss: 6099.1055 - x_logits_loss: 6096.2622 - x_logpdf_loss: -1.3894e+00 - z_latents_loss: 2.8478 - val_loss: 2925.3818 - val_x_logits_loss: 2922.9414 - val_x_logpdf_loss: -1.3911e+00 - val_z_latents_loss: 2.7813
# Epoch 00048: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_2:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:17:33, 27.95s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 300it [2:14:13, 26.18s/it]
# inception_score mean: [3.83861631e+83], sigma: 1.318099958688147e+168

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 300it [04:31,  1.12it/s]
# perceptual path length score: 4683.65869140625

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00228882s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00186515s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.0016098s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00204587s
# recall score: [1.]
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 71.05it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 40.35it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 43.63it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 43.20it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 98.72it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 3it [00:00, 27.00it/s]
# 10it [00:00, 26.85it/s]
# 3it [00:00, 27.18it/s]
# 10it [00:00, 26.62it/s]
# 3it [00:00, 22.48it/s]
# 10it [00:00, 23.78it/s]
# 3it [00:00, 24.35it/s]
# 10it [00:00, 23.75it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.37it/s]
# 10it [00:00, 27.60it/s]
