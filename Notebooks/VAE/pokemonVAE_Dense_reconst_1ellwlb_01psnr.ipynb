# %% [markdown]
# complete Training and testing Done except frechet

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 15891, done.
# remote: Total 15891 (delta 0), reused 0 (delta 0), pack-reused 15891
# Receiving objects: 100% (15891/15891), 733.46 MiB | 43.39 MiB/s, done.
# Resolving deltas: 100% (10845/10845), done.
# Checking out files: 100% (1697/1697), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
import numpy as np
_instance_scale=1.0
for data in val_generator:
    print(np.max(data['images']))
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([100, 100, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
menc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

venc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'VAE_Dense_reconst_1ellwlb_01psnr'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr

# %%
from training.autoencoding_basic.autoencoders.VAE import VAE as AE

# %%
#inputs_shape=image_size

# %%
variables_params = \
[
    {
        'name': 'inference_mean', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': menc_lays
    },
    
    {
        'name': 'inference_logvariance', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': venc_lays
    },
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   ERROR    | Faild to restore old models !
#   ERROR    | Faild to restore old models !
#   WARNING  | None
#   WARNING  | None
# SavedModel file does not exist at: /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir/pokemonVAE_Dense_reconst_1ellwlb_01psnr_inference_mean.hdf5/{saved_model.pbtxt|saved_model.pb}
#
#
# Model: "inference_mean"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_mean_inputs (Input [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten (Flatten)            (None, 250000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_mean_outputs (Acti (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
#   WARNING  | None
#   WARNING  | None
# Model: "inference_logvariance"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_logvariance_inputs [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 250000)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100)               0
# _________________________________________________________________
# inference_logvariance_output (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_8 (Dense)              (None, 30000)             1530000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_2 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 1,545,162
# Trainable params: 1,545,156
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.peak_signal_to_noise_ratio import prepare_psnr
from statistical.losses_utilities import similarity_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+ 0.1*similarity_to_distance(prepare_psnr([ae.batch_size]+ae.get_inputs_shape()))(x_true, x_logits)})
# Out:
# Model: "pokemonVAE_Dense_reconst_1ellwlb_01psnr"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inference_logvariance_inputs (I [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# inference_logvariance (Function (None, 100)          25001250    inference_logvariance_inputs[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# inference_mean_inputs (InputLay [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(10, 100)]          0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# inference_mean (Functional)     (None, 100)          25001250    inference_mean_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_z_latents (TensorFl [(10, 100)]          0           tf_op_layer_Mul_1[0][0]
#                                                                  inference_mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 100)]        0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(10, 100)]          0           tf_op_layer_z_latents[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [(None, 100)]        0           inference_mean[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference ( [(10, 100)]          0           tf_op_layer_RealDiv[0][0]
#                                                                  tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(10, 100)]          0           tf_op_layer_SquaredDifference[0][
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 100)]        0           tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# generative (Functional)         (None, 100, 100, 3)  1545162     tf_op_layer_z_latents[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(10, 100)]          0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_x_logits (TensorFlo [(10, 100, 100, 3)]  0           generative[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_logpdf (TensorFlowO [(10, 100)]          0           tf_op_layer_Sub[0][0]
# ==================================================================================================
# Total params: 51,547,662
# Trainable params: 51,547,256
# Non-trainable params: 406
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=1e-12, 
    patience=12, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/csv_dir/pokemonVAE_Dense_reconst_1ellwlb_01psnr.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=train_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 7485.77832, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 -
saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 198s - loss: 5935.8604 - x_logits_loss: 5933.2026 - x_logpdf_loss: -1.4003e+00 - z_latents_loss: 3.0735 - val_loss: 2607.5657 - val_x_logits_loss: 2605.1521 - val_x_logpdf_loss: -1.4121e+00 - val_z_latents_loss: 2.9150
# Epoch 27/1000000
#
# Epoch 00027: loss improved from 5935.86035 to 5931.67529, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 198s - loss: 5931.6753 - x_logits_loss: 5928.9971 - x_logpdf_loss: -1.4004e+00 - z_latents_loss: 3.0693 - val_loss: 2686.3213 - val_x_logits_loss: 2683.9094 - val_x_logpdf_loss: -1.4008e+00 - val_z_latents_loss: 2.9342
# Epoch 28/1000000
#
# Epoch 00028: loss improved from 5931.67529 to 5921.56494, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 201s - loss: 5921.5649 - x_logits_loss: 5918.8555 - x_logpdf_loss: -1.4002e+00 - z_latents_loss: 3.0621 - val_loss: 2621.2327 - val_x_logits_loss: 2618.7124 - val_x_logpdf_loss: -1.3997e+00 - val_z_latents_loss: 2.9282
# Epoch 29/1000000
#
# Epoch 00029: loss improved from 5921.56494 to 5918.06152, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 201s - loss: 5918.0615 - x_logits_loss: 5915.3394 - x_logpdf_loss: -1.4004e+00 - z_latents_loss: 3.0513 - val_loss: 2711.2495 - val_x_logits_loss: 2708.8767 - val_x_logpdf_loss: -1.3197e+00 - val_z_latents_loss: 2.8004
# Epoch 30/1000000
#
# Epoch 00030: loss did not improve from 5918.06152
# 5000/5000 - 200s - loss: 5925.8267 - x_logits_loss: 5923.0879 - x_logpdf_loss: -1.3983e+00 - z_latents_loss: 3.0331 - val_loss: 2644.7346 - val_x_logits_loss: 2642.3662 - val_x_logpdf_loss: -1.3971e+00 - val_z_latents_loss: 2.8133
# Epoch 31/1000000
#
# Epoch 00031: loss improved from 5918.06152 to 5908.95020, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 200s - loss: 5908.9502 - x_logits_loss: 5906.2036 - x_logpdf_loss: -1.3995e+00 - z_latents_loss: 3.0197 - val_loss: 2617.1770 - val_x_logits_loss: 2614.6726 - val_x_logpdf_loss: -1.4037e+00 - val_z_latents_loss: 2.8827
# Epoch 32/1000000
#
# Epoch 00032: loss improved from 5908.95020 to 5896.60205, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 202s - loss: 5896.6021 - x_logits_loss: 5893.8560 - x_logpdf_loss: -1.4014e+00 - z_latents_loss: 3.0168 - val_loss: 2720.4902 - val_x_logits_loss: 2718.1372 - val_x_logpdf_loss: -1.3798e+00 - val_z_latents_loss: 2.8371
# Epoch 33/1000000
#
# Epoch 00033: loss did not improve from 5896.60205
# 5000/5000 - 197s - loss: 5903.8701 - x_logits_loss: 5901.0981 - x_logpdf_loss: -1.4012e+00 - z_latents_loss: 3.0038 - val_loss: 2607.7942 - val_x_logits_loss: 2605.2207 - val_x_logpdf_loss: -1.4007e+00 - val_z_latents_loss: 2.8974
# Epoch 34/1000000
#
# Epoch 00034: loss did not improve from 5896.60205
# 5000/5000 - 199s - loss: 5912.0376 - x_logits_loss: 5909.2627 - x_logpdf_loss: -1.4013e+00 - z_latents_loss: 2.9899 - val_loss: 2695.1917 - val_x_logits_loss: 2692.8105 - val_x_logpdf_loss: -1.4151e+00 - val_z_latents_loss: 2.8352
# Epoch 35/1000000
#
# Epoch 00035: loss did not improve from 5896.60205
# 5000/5000 - 199s - loss: 5907.6133 - x_logits_loss: 5904.8081 - x_logpdf_loss: -1.4026e+00 - z_latents_loss: 2.9826 - val_loss: 2608.5645 - val_x_logits_loss: 2606.0784 - val_x_logpdf_loss: -1.3876e+00 - val_z_latents_loss: 2.8245
# Epoch 36/1000000
#
# Epoch 00036: loss improved from 5896.60205 to 5895.73242, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 202s - loss: 5895.7324 - x_logits_loss: 5892.9326 - x_logpdf_loss: -1.4015e+00 - z_latents_loss: 2.9731 - val_loss: 2704.5569 - val_x_logits_loss: 2701.8936 - val_x_logpdf_loss: -1.3714e+00 - val_z_latents_loss: 2.9540
# Epoch 37/1000000
#
# Epoch 00037: loss did not improve from 5895.73242
# 5000/5000 - 198s - loss: 5900.5957 - x_logits_loss: 5897.7886 - x_logpdf_loss: -1.4016e+00 - z_latents_loss: 2.9608 - val_loss: 2700.1191 - val_x_logits_loss: 2697.7590 - val_x_logpdf_loss: -1.4057e+00 - val_z_latents_loss: 2.7782
# Epoch 38/1000000
#
# Epoch 00038: loss did not improve from 5895.73242
# 5000/5000 - 198s - loss: 5900.0884 - x_logits_loss: 5897.2622 - x_logpdf_loss: -1.4022e+00 - z_latents_loss: 2.9533 - val_loss: 5622.4404 - val_x_logits_loss: 5611.2241 - val_x_logpdf_loss: -1.4557e+00 - val_z_latents_loss: 11.0941
# Epoch 39/1000000
#
# Epoch 00039: loss did not improve from 5895.73242
# 5000/5000 - 198s - loss: 5897.1992 - x_logits_loss: 5894.3672 - x_logpdf_loss: -1.4021e+00 - z_latents_loss: 2.9429 - val_loss: 2695.2026 - val_x_logits_loss: 2692.8325 - val_x_logpdf_loss: -1.4063e+00 - val_z_latents_loss: 2.7320
# Epoch 40/1000000
#
# Epoch 00040: loss improved from 5895.73242 to 5889.70557, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 200s - loss: 5889.7056 - x_logits_loss: 5886.8857 - x_logpdf_loss: -1.4039e+00 - z_latents_loss: 2.9310 - val_loss: 21872.8887 - val_x_logits_loss: 21823.6680 - val_x_logpdf_loss: -1.4887e+00 - val_z_latents_loss: 35.2768
# Epoch 41/1000000
#
# Epoch 00041: loss did not improve from 5889.70557
# 5000/5000 - 199s - loss: 5889.8560 - x_logits_loss: 5887.0210 - x_logpdf_loss: -1.4039e+00 - z_latents_loss: 2.9238 - val_loss: 2697.8931 - val_x_logits_loss: 2695.5862 - val_x_logpdf_loss: -1.4014e+00 - val_z_latents_loss: 2.6957
# Epoch 42/1000000
#
# Epoch 00042: loss improved from 5889.70557 to 5888.26514, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 200s - loss: 5888.2651 - x_logits_loss: 5885.4053 - x_logpdf_loss: -1.4054e+00 - z_latents_loss: 2.9160 - val_loss: 2601.8682 - val_x_logits_loss: 2599.3330 - val_x_logpdf_loss: -1.3980e+00 - val_z_latents_loss: 2.7608
# Epoch 43/1000000
#
# Epoch 00043: loss improved from 5888.26514 to 5882.57715, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 198s - loss: 5882.5771 - x_logits_loss: 5879.7227 - x_logpdf_loss: -1.4044e+00 - z_latents_loss: 2.9069 - val_loss: 2594.0337 - val_x_logits_loss: 2591.5432 - val_x_logpdf_loss: -1.4095e+00 - val_z_latents_loss: 2.7349
# Epoch 44/1000000
#
# Epoch 00044: loss did not improve from 5882.57715
# 5000/5000 - 197s - loss: 5883.6558 - x_logits_loss: 5880.8008 - x_logpdf_loss: -1.4048e+00 - z_latents_loss: 2.8985 - val_loss: 2655.8921 - val_x_logits_loss: 2653.5032 - val_x_logpdf_loss: -1.3918e+00 - val_z_latents_loss: 2.6546
# Epoch 45/1000000
#
# Epoch 00045: loss improved from 5882.57715 to 5879.33936, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 200s - loss: 5879.3394 - x_logits_loss: 5876.4673 - x_logpdf_loss: -1.4047e+00 - z_latents_loss: 2.8933 - val_loss: 2651.6577 - val_x_logits_loss: 2649.3035 - val_x_logpdf_loss: -1.3904e+00 - val_z_latents_loss: 2.6615
# Epoch 46/1000000
#
# Epoch 00046: loss did not improve from 5879.33936
# 5000/5000 - 198s - loss: 5885.8228 - x_logits_loss: 5882.9346 - x_logpdf_loss: -1.4041e+00 - z_latents_loss: 2.8870 - val_loss: 2543.1182 - val_x_logits_loss: 2540.4502 - val_x_logpdf_loss: -1.3999e+00 - val_z_latents_loss: 2.7679
# Epoch 47/1000000
#
# Epoch 00047: loss improved from 5879.33936 to 5873.77686, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 199s - loss: 5873.7769 - x_logits_loss: 5870.8926 - x_logpdf_loss: -1.4047e+00 - z_latents_loss: 2.8791 - val_loss: 5626.5293 - val_x_logits_loss: 5618.3496 - val_x_logpdf_loss: -1.4548e+00 - val_z_latents_loss: 6.4411
# Epoch 48/1000000
#
# Epoch 00048: loss did not improve from 5873.77686
# 5000/5000 - 198s - loss: 5879.0322 - x_logits_loss: 5876.1460 - x_logpdf_loss: -1.4049e+00 - z_latents_loss: 2.8685 - val_loss: 2642.9417 - val_x_logits_loss: 2640.5042 - val_x_logpdf_loss: -1.4020e+00 - val_z_latents_loss: 2.6812
# Epoch 49/1000000
#
# Epoch 00049: loss improved from 5873.77686 to 5873.64648, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 199s - loss: 5873.6465 - x_logits_loss: 5870.7373 - x_logpdf_loss: -1.4066e+00 - z_latents_loss: 2.8612 - val_loss: 2603.9331 - val_x_logits_loss: 2601.3540 - val_x_logpdf_loss: -1.3508e+00 - val_z_latents_loss: 2.6954
# Epoch 50/1000000
#
# Epoch 00050: loss improved from 5873.64648 to 5868.27002, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 199s - loss: 5868.2700 - x_logits_loss: 5865.3628 - x_logpdf_loss: -1.4078e+00 - z_latents_loss: 2.8460 - val_loss: 2637.3696 - val_x_logits_loss: 2634.9436 - val_x_logpdf_loss: -1.3481e+00 - val_z_latents_loss: 2.5903
# Epoch 51/1000000
#
# Epoch 00051: loss did not improve from 5868.27002
# 5000/5000 - 199s - loss: 5869.2935 - x_logits_loss: 5866.3979 - x_logpdf_loss: -1.4078e+00 - z_latents_loss: 2.8348 - val_loss: 2621.1152 - val_x_logits_loss: 2618.4580 - val_x_logpdf_loss: -1.4346e+00 - val_z_latents_loss: 2.8084
# Epoch 52/1000000
#
# Epoch 00052: loss did not improve from 5868.27002
# 5000/5000 - 198s - loss: 5869.6621 - x_logits_loss: 5866.7534 - x_logpdf_loss: -1.4067e+00 - z_latents_loss: 2.8194 - val_loss: 2670.6487 - val_x_logits_loss: 2668.1919 - val_x_logpdf_loss: -1.4125e+00 - val_z_latents_loss: 2.6662
# Epoch 53/1000000
#
# Epoch 00053: loss did not improve from 5868.27002
# 5000/5000 - 198s - loss: 5886.0425 - x_logits_loss: 5883.1377 - x_logpdf_loss: -1.4047e+00 - z_latents_loss: 2.8043 - val_loss: 2551.7478 - val_x_logits_loss: 2548.6606 - val_x_logpdf_loss: -1.4023e+00 - val_z_latents_loss: 2.9401
# Epoch 54/1000000
#
# Epoch 00054: loss improved from 5868.27002 to 5862.41992, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ellwlb_01psnr/var_save_dir
# 5000/5000 - 199s - loss: 5862.4199 - x_logits_loss: 5859.5098 - x_logpdf_loss: -1.4058e+00 - z_latents_loss: 2.7998 - val_loss: 2669.5386 - val_x_logits_loss: 2666.3755 - val_x_logpdf_loss: -1.4027e+00 - val_z_latents_loss: 3.0023
# Epoch 55/1000000
#
# Epoch 00055: loss did not improve from 5862.41992
# 5000/5000 - 197s - loss: 5871.7607 - x_logits_loss: 5868.8472 - x_logpdf_loss: -1.4070e+00 - z_latents_loss: 2.7908 - val_loss: 3459.9009 - val_x_logits_loss: 3455.1497 - val_x_logpdf_loss: -1.4026e+00 - val_z_latents_loss: 3.9477
# Epoch 56/1000000
#
# Epoch 00056: loss did not improve from 5862.41992
# 5000/5000 - 198s - loss: 5878.1030 - x_logits_loss: 5875.1802 - x_logpdf_loss: -1.4082e+00 - z_latents_loss: 2.7876 - val_loss: 4534.5552 - val_x_logits_loss: 4529.8359 - val_x_logpdf_loss: -1.4019e+00 - val_z_latents_loss: 4.1067
# Epoch 57/1000000
#
# Epoch 00057: loss did not improve from 5862.41992
# 5000/5000 - 197s - loss: 5890.4570 - x_logits_loss: 5887.5366 - x_logpdf_loss: -1.4079e+00 - z_latents_loss: 2.7818 - val_loss: 3370.2449 - val_x_logits_loss: 3365.0710 - val_x_logpdf_loss: -1.4031e+00 - val_z_latents_loss: 3.8651
# Epoch 58/1000000
#
# Epoch 00058: loss did not improve from 5862.41992
# 5000/5000 - 197s - loss: 5967.6538 - x_logits_loss: 5964.7476 - x_logpdf_loss: -1.4070e+00 - z_latents_loss: 2.7786 - val_loss: 4005.7466 - val_x_logits_loss: 4000.7168 - val_x_logpdf_loss: -1.4087e+00 - val_z_latents_loss: 4.0499
# Epoch 59/1000000
#
# Epoch 00059: loss did not improve from 5862.41992
# 5000/5000 - 198s - loss: 6167.5435 - x_logits_loss: 6164.6392 - x_logpdf_loss: -1.4051e+00 - z_latents_loss: 2.7847 - val_loss: 10262.1006 - val_x_logits_loss: 10252.5752 - val_x_logpdf_loss: -1.4097e+00 - val_z_latents_loss: 7.5896
# Epoch 60/1000000
#
# Epoch 00060: loss did not improve from 5862.41992
# 5000/5000 - 197s - loss: 6392.3457 - x_logits_loss: 6389.4829 - x_logpdf_loss: -1.4010e+00 - z_latents_loss: 2.8091 - val_loss: 20136.4180 - val_x_logits_loss: 20114.5801 - val_x_logpdf_loss: -1.3913e+00 - val_z_latents_loss: 14.5032
# Epoch 61/1000000
#
# Epoch 00061: loss did not improve from 5862.41992
# 5000/5000 - 198s - loss: 6741.7793 - x_logits_loss: 6738.9189 - x_logpdf_loss: -1.3939e+00 - z_latents_loss: 2.8477 - val_loss: 13104.4414 - val_x_logits_loss: 13089.9482 - val_x_logpdf_loss: -1.3862e+00 - val_z_latents_loss: 9.3740
# Epoch 62/1000000
#
# Epoch 00062: loss did not improve from 5862.41992
# 5000/5000 - 202s - loss: 7125.0312 - x_logits_loss: 7122.1982 - x_logpdf_loss: -1.3880e+00 - z_latents_loss: 2.9032 - val_loss: 11702.1992 - val_x_logits_loss: 11688.9072 - val_x_logpdf_loss: -1.3936e+00 - val_z_latents_loss: 9.0197
# Epoch 63/1000000
#
# Epoch 00063: loss did not improve from 5862.41992
# 5000/5000 - 201s - loss: 6867.2754 - x_logits_loss: 6864.4443 - x_logpdf_loss: -1.3873e+00 - z_latents_loss: 2.9309 - val_loss: 8852.2910 - val_x_logits_loss: 8840.1963 - val_x_logpdf_loss: -1.3858e+00 - val_z_latents_loss: 9.0689
# Epoch 64/1000000
#
# Epoch 00064: loss did not improve from 5862.41992
# 5000/5000 - 203s - loss: 6771.6724 - x_logits_loss: 6768.8467 - x_logpdf_loss: -1.3887e+00 - z_latents_loss: 2.9424 - val_loss: 5169.3662 - val_x_logits_loss: 5163.8560 - val_x_logpdf_loss: -1.3885e+00 - val_z_latents_loss: 4.9393
# Epoch 65/1000000
#
# Epoch 00065: loss did not improve from 5862.41992
# 5000/5000 - 205s - loss: 6577.1582 - x_logits_loss: 6574.3145 - x_logpdf_loss: -1.3896e+00 - z_latents_loss: 2.9448 - val_loss: 22261.0117 - val_x_logits_loss: 22232.4922 - val_x_logpdf_loss: -1.3868e+00 - val_z_latents_loss: 18.3336
# Epoch 66/1000000
#
# Epoch 00066: loss did not improve from 5862.41992
# 5000/5000 - 205s - loss: 6576.3721 - x_logits_loss: 6573.5166 - x_logpdf_loss: -1.3898e+00 - z_latents_loss: 2.9500 - val_loss: 12332.5000 - val_x_logits_loss: 12316.4404 - val_x_logpdf_loss: -1.3886e+00 - val_z_latents_loss: 11.9639
# Epoch 00066: early stopping

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:14:51, 26.44s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 300it [2:13:46, 26.14s/it]
# inception_score mean: [1.87972798e+98], sigma: 2.227893796356598e+197

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 300it [04:32,  1.09it/s]
# perceptual path length score: 4278.17431640625

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00238323s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00211978s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00235534s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00188589s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 74.37it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 41.06it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 43.04it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 42.74it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 68.57it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 3it [00:00, 26.50it/s]
# 10it [00:00, 25.76it/s]
# 3it [00:00, 26.56it/s]
# 10it [00:00, 25.50it/s]
# 3it [00:00, 25.63it/s]
# 10it [00:00, 26.70it/s]
# 3it [00:00, 27.01it/s]
# 10it [00:00, 26.74it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.46it/s]
# 10it [00:00, 27.16it/s]
