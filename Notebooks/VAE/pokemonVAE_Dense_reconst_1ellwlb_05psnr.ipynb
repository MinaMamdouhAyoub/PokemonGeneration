# %% [markdown]
# Training Done (redo metrics)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Environment prep for Colab
#  - download git repo
#  - install required pip packages

# %%
# !git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# %cd /content/
# Out:
# Cloning into 'Generative_Models'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 16171 (delta 0), reused 3 (delta 0), pack-reused 16162
# Receiving objects: 100% (16171/16171), 1.00 GiB | 39.94 MiB/s, done.
# Resolving deltas: 100% (11012/11012), done.
# Checking out files: 100% (1688/1688), done.
# /content/Generative_Models
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well!git clone https://github.com/kkahloots/Generative_Models.git # this is for loading git with correct brach
# %cd /content/Generative_Models/
# !pip -q install -r /content/Generative_Models/requirements.txt
# !pip install colorlog==4.0.2
# %cd /content/
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists
# /content/Generative_Models
# Collecting colorlog==4.0.2
#   Downloading https://files.pythonhosted.org/packages/68/4d/892728b0c14547224f0ac40884e722a3d00cb54e7a146aea0b3186806c9e/colorlog-4.0.2-py2.py3-none-any.whl
# Installing collected packages: colorlog
#   Found existing installation: colorlog 4.6.2
#     Uninstalling colorlog-4.6.2:
#       Successfully uninstalled colorlog-4.6.2
# Successfully installed colorlog-4.0.2
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Connect Drive to save and restore results

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir /content/drive/My\ Drive/Results
MAIN_SAVE_DIR = '/content/drive/My Drive/Results'
IMG_DIR = '/content/Generative_Models/data/.pokemon' #change .qbert here as well
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Results’: File exists

# %% [markdown]
# # Settings

# %%
# %env TF_KERAS = 1
import os
sep_local = os.path.sep

import sys
sys.path.append('..'+sep_local+'..')
print(sep_local)
# Out:
# env: TF_KERAS=1
# /

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
#os.chdir('..'+sep_local+'..'+sep_local+'..'+sep_local+'..'+sep_local+'..')
os.chdir('/content/Generative_Models')
print(os.getcwd())
# Out:
# /content/Generative_Models

# %% [markdown]
# # only on colab

# %%
# !cat data/.pokemon/pokemon.tar.part* > data/.pokemon/pokemon.tar

# %%
# !tar -xvf data/.pokemon/pokemon.tar --directory data/.pokemon/
# Out:
# Pokemon_LMDB/_training/
# Pokemon_LMDB/_training/lock.mdb
# Pokemon_LMDB/_training/data.mdb
# Pokemon_LMDB/_validation/
# Pokemon_LMDB/_validation/lock.mdb
# Pokemon_LMDB/_validation/data.mdb
# Pokemon_LMDB/meta_info.json

# %% [markdown]
# # Dataset loading

# %%
from training.generators.from_lmdb.lmdb_image_generator import get_generators

# %%
dataset_name='pokemon'
inputs_shape= image_shape=(100, 100, 3)
batch_size = 10
latents_dim = 100
intermediate_dim = 50
lmdb_dir = 'data/.pokemon/Pokemon_LMDB'

# %%
from transformation.lmdb_transformer import LmdbTransformer

# %%
train_generator, val_generator = get_generators(
        lmdb_dir=lmdb_dir,
        batch_size=batch_size,
        episode_len=None,
        episode_shift=None
)
# Out:
# /content/Generative_Models/transformation/file_image_generator.py:51: UserWarning: No files found
#   warnings.warn(msg)
# Initializing Iterator training Number of images 591
# Initializing Iterator validation Number of images 218

# %%
import numpy as np
_instance_scale=1.0
for data in val_generator:
    print(np.max(data['images']))
    break
    #print(data.keys())
# Out:
# 1.0

# %%
data['images'][0].shape
# Out:
# TensorShape([400, 400, 3])

# %%
data.keys()
# Out:
# dict_keys(['images', 'label'])

# %% [markdown]
# # Model's Layers definition

# %%
import numpy as np
from collections.abc import Iterable
if isinstance(inputs_shape, Iterable):
    flat_outputs_shape = np.prod(inputs_shape)
flat_outputs_shape
# Out:
# 30000

# %%
menc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

venc_lays = [tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim//2, activation='relu'),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(units=latents_dim)]

dec_lays = [tf.keras.layers.Dense(units=latents_dim, activation='relu'),
            tf.keras.layers.Dense(units=intermediate_dim, activation='relu'),
            tf.keras.layers.Dense(units=flat_outputs_shape),
            tf.keras.layers.Reshape(inputs_shape)]

# %% [markdown]
# # Model definition

# %%
model_name = dataset_name+'VAE_Dense_reconst_1ell_05psnr'
experiments_dir='/content/drive/My Drive/Results'+sep_local+model_name
print(experiments_dir)
# Out:
# /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr

# %%
from training.autoencoding_basic.autoencoders.VAE import VAE as AE

# %%
#inputs_shape=image_size

# %%
variables_params = \
[
    {
        'name': 'inference_mean', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': menc_lays
    },
    
    {
        'name': 'inference_logvariance', 
        'inputs_shape':inputs_shape,
        'outputs_shape':latents_dim,
        'layers': venc_lays
    },
        {
        'name': 'generative', 
        'inputs_shape':latents_dim,
        'outputs_shape':inputs_shape,
        'layers':dec_lays
    }
]

# %%
from utils.data_and_files.file_utils import create_if_not_exist

# %%
_restore = os.path.join(experiments_dir, 'var_save_dir')

# %%
create_if_not_exist(_restore)
_restore
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir'

# %%
#to restore trained model, set filepath=_restore

# %%
ae = AE( 
    name=model_name,
    latents_dim=latents_dim,
    batch_size=batch_size,
    variables_params=variables_params, 
    filepath=_restore
    )
# Out:
#   DEBUG    | Restore old models ...
#   DEBUG    | Restore old models ...
#   WARNING  | None
#   WARNING  | None
# Model: "inference_mean"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_mean_inputs (Input [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense (Dense)                (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten (Flatten)            (None, 250000)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization (BatchNo (None, 100)               400
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# activity_regularization (Act (None, 100)               0
# _________________________________________________________________
# inference_mean_outputs (Acti (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "inference_logvariance"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inference_logvariance_inputs [(None, 100, 100, 3)]     0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100, 100, 25)      100
# _________________________________________________________________
# dense_4 (Dense)              (None, 100, 100, 25)      650
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 250000)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               25000100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# activity_regularization_1 (A (None, 100)               0
# _________________________________________________________________
# inference_logvariance_output (None, 100)               0
# =================================================================
# Total params: 25,001,250
# Trainable params: 25,001,050
# Non-trainable params: 200
# _________________________________________________________________
#   WARNING  | None
#   WARNING  | None
# Model: "generative"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generative_inputs (InputLaye [(None, 100)]             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_8 (Dense)              (None, 30000)             1530000
# _________________________________________________________________
# reshape (Reshape)            (None, 100, 100, 3)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 100, 3)       12
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 100, 3)       0
# _________________________________________________________________
# activity_regularization_2 (A (None, 100, 100, 3)       0
# _________________________________________________________________
# generative_outputs (Activati (None, 100, 100, 3)       0
# =================================================================
# Total params: 1,545,162
# Trainable params: 1,545,156
# Non-trainable params: 6
# _________________________________________________________________

# %%
from evaluation.quantitive_metrics.peak_signal_to_noise_ratio import prepare_psnr
from statistical.losses_utilities import similarity_to_distance
from statistical.ae_losses import expected_loglikelihood_with_lower_bound as ellwlb

# %%
ae.compile(loss={'x_logits': lambda x_true, x_logits: ellwlb(x_true, x_logits)+ 0.5*similarity_to_distance(prepare_psnr([ae.batch_size]+ae.get_inputs_shape()))(x_true, x_logits)})
# Out:
# Model: "pokemonVAE_Dense_reconst_1ell_05psnr"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inference_logvariance_inputs (I [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# inference_logvariance (Function (None, 100)          25001250    inference_logvariance_inputs[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Mul[0][0]
# __________________________________________________________________________________________________
# inference_mean_inputs (InputLay [(None, 100, 100, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(10, 100)]          0           tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# inference_mean (Functional)     (None, 100)          25001250    inference_mean_inputs[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 100)]        0           inference_logvariance[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_z_latents (TensorFl [(10, 100)]          0           tf_op_layer_Mul_1[0][0]
#                                                                  inference_mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sqrt (TensorFlowOpL [(None, 100)]        0           tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(10, 100)]          0           tf_op_layer_z_latents[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_1 (TensorFl [(None, 100)]        0           inference_mean[0][0]
#                                                                  tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference ( [(10, 100)]          0           tf_op_layer_RealDiv[0][0]
#                                                                  tf_op_layer_RealDiv_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 100)]        0           tf_op_layer_Sqrt[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(10, 100)]          0           tf_op_layer_SquaredDifference[0][
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 100)]        0           tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# generative (Functional)         (None, 100, 100, 3)  1545162     tf_op_layer_z_latents[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(10, 100)]          0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_x_logits (TensorFlo [(10, 100, 100, 3)]  0           generative[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_logpdf (TensorFlowO [(10, 100)]          0           tf_op_layer_Sub[0][0]
# ==================================================================================================
# Total params: 51,547,662
# Trainable params: 51,547,256
# Non-trainable params: 406
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Callbacks

# %%
from training.callbacks.sample_generation import SampleGeneration
from training.callbacks.save_model import ModelSaver

# %%
es = tf.keras.callbacks.EarlyStopping(
    monitor='loss', 
    min_delta=1e-12, 
    patience=12, 
    verbose=1, 
    restore_best_weights=False
)

# %%
ms = ModelSaver(filepath=_restore)

# %%
csv_dir = os.path.join(experiments_dir, 'csv_dir')
create_if_not_exist(csv_dir)
csv_dir = os.path.join(csv_dir, ae.name+'.csv')
csv_log = tf.keras.callbacks.CSVLogger(csv_dir, append=True)
csv_dir
# Out:
# '/content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/csv_dir/pokemonVAE_Dense_reconst_1ell_05psnr.csv'

# %%
image_gen_dir = os.path.join(experiments_dir, 'image_gen_dir')
create_if_not_exist(image_gen_dir)

# %%
sg = SampleGeneration(latents_shape=latents_dim, filepath=image_gen_dir, gen_freq=5, save_img=True, gray_plot=False)

# %% [markdown]
# # Model Training

# %%
ae.fit(
    x=train_generator,
    input_kw='images',
    steps_per_epoch=int(5e3),
    epochs=int(1e6), 
    verbose=2,
    callbacks=[es, ms, csv_log, sg],
    workers=-1,
    use_multiprocessing=True,
    validation_data=train_generator,
    validation_steps=int(1e4)
)
# Out:
# Epoch 1/1000000
#
# Epoch 00001: loss improved from inf to 7485.53906, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 -
# Epoch 34/1000000
#
# Epoch 00034: loss did not improve from 5886.40381
# 5000/5000 - 198s - loss: 5898.7212 - x_logits_loss: 5895.9102 - x_logpdf_loss: -1.3679e+00 - z_latents_loss: 2.9430 - val_loss: 2582.1223 - val_x_logits_loss: 2579.6025 - val_x_logpdf_loss: -1.3740e+00 - val_z_latents_loss: 2.7951
# Epoch 35/1000000
#
# Epoch 00035: loss did not improve from 5886.40381
# 5000/5000 - 197s - loss: 5897.4072 - x_logits_loss: 5894.6084 - x_logpdf_loss: -1.3669e+00 - z_latents_loss: 2.9328 - val_loss: 2646.3589 - val_x_logits_loss: 2643.9260 - val_x_logpdf_loss: -1.3676e+00 - val_z_latents_loss: 2.7665
# Epoch 36/1000000
#
# Epoch 00036: loss improved from 5886.40381 to 5882.54590, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 201s - loss: 5882.5459 - x_logits_loss: 5879.7178 - x_logpdf_loss: -1.3660e+00 - z_latents_loss: 2.9237 - val_loss: 2649.9690 - val_x_logits_loss: 2647.4700 - val_x_logpdf_loss: -1.3686e+00 - val_z_latents_loss: 2.7771
# Epoch 37/1000000
#
# Epoch 00037: loss did not improve from 5882.54590
# 5000/5000 - 198s - loss: 5891.2666 - x_logits_loss: 5888.4175 - x_logpdf_loss: -1.3675e+00 - z_latents_loss: 2.9172 - val_loss: 2672.6960 - val_x_logits_loss: 2670.3325 - val_x_logpdf_loss: -1.3684e+00 - val_z_latents_loss: 2.7154
# Epoch 38/1000000
#
# Epoch 00038: loss did not improve from 5882.54590
# 5000/5000 - 197s - loss: 5888.3955 - x_logits_loss: 5885.5493 - x_logpdf_loss: -1.3685e+00 - z_latents_loss: 2.9080 - val_loss: 2597.2886 - val_x_logits_loss: 2594.7227 - val_x_logpdf_loss: -1.3744e+00 - val_z_latents_loss: 2.7916
# Epoch 39/1000000
#
# Epoch 00039: loss did not improve from 5882.54590
# 5000/5000 - 198s - loss: 5885.9482 - x_logits_loss: 5883.1016 - x_logpdf_loss: -1.3688e+00 - z_latents_loss: 2.8992 - val_loss: 2640.5457 - val_x_logits_loss: 2638.0601 - val_x_logpdf_loss: -1.3682e+00 - val_z_latents_loss: 2.7352
# Epoch 40/1000000
#
# Epoch 00040: loss improved from 5882.54590 to 5880.52979, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 199s - loss: 5880.5298 - x_logits_loss: 5877.6753 - x_logpdf_loss: -1.3670e+00 - z_latents_loss: 2.8890 - val_loss: 2580.3669 - val_x_logits_loss: 2577.8191 - val_x_logpdf_loss: -1.3705e+00 - val_z_latents_loss: 2.7355
# Epoch 41/1000000
#
# Epoch 00041: loss improved from 5880.52979 to 5880.08301, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 202s - loss: 5880.0830 - x_logits_loss: 5877.2188 - x_logpdf_loss: -1.3664e+00 - z_latents_loss: 2.8803 - val_loss: 2594.1750 - val_x_logits_loss: 2591.6489 - val_x_logpdf_loss: -1.3707e+00 - val_z_latents_loss: 2.7105
# Epoch 42/1000000
#
# Epoch 00042: loss improved from 5880.08301 to 5876.57275, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 199s - loss: 5876.5728 - x_logits_loss: 5873.6987 - x_logpdf_loss: -1.3679e+00 - z_latents_loss: 2.8729 - val_loss: 2691.5234 - val_x_logits_loss: 2689.1917 - val_x_logpdf_loss: -1.3613e+00 - val_z_latents_loss: 2.6351
# Epoch 43/1000000
#
# Epoch 00043: loss improved from 5876.57275 to 5872.17969, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 199s - loss: 5872.1797 - x_logits_loss: 5869.3145 - x_logpdf_loss: -1.3675e+00 - z_latents_loss: 2.8656 - val_loss: 2587.5518 - val_x_logits_loss: 2585.0076 - val_x_logpdf_loss: -1.3729e+00 - val_z_latents_loss: 2.7104
# Epoch 44/1000000
#
# Epoch 00044: loss did not improve from 5872.17969
# 5000/5000 - 198s - loss: 5872.3633 - x_logits_loss: 5869.4629 - x_logpdf_loss: -1.3697e+00 - z_latents_loss: 2.8606 - val_loss: 2691.4924 - val_x_logits_loss: 2688.8467 - val_x_logpdf_loss: -1.3627e+00 - val_z_latents_loss: 2.7947
# Epoch 45/1000000
#
# Epoch 00045: loss improved from 5872.17969 to 5870.88330, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 199s - loss: 5870.8833 - x_logits_loss: 5867.9751 - x_logpdf_loss: -1.3698e+00 - z_latents_loss: 2.8531 - val_loss: 2627.2549 - val_x_logits_loss: 2624.7493 - val_x_logpdf_loss: -1.3654e+00 - val_z_latents_loss: 2.6915
# Epoch 46/1000000
#
# Epoch 00046: loss did not improve from 5870.88330
# 5000/5000 - 198s - loss: 5873.5620 - x_logits_loss: 5870.6606 - x_logpdf_loss: -1.3716e+00 - z_latents_loss: 2.8467 - val_loss: 2608.8804 - val_x_logits_loss: 2606.3699 - val_x_logpdf_loss: -1.3708e+00 - val_z_latents_loss: 2.6820
# Epoch 47/1000000
#
# Epoch 00047: loss improved from 5870.88330 to 5863.23145, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 199s - loss: 5863.2314 - x_logits_loss: 5860.3091 - x_logpdf_loss: -1.3716e+00 - z_latents_loss: 2.8418 - val_loss: 2604.7312 - val_x_logits_loss: 2602.1885 - val_x_logpdf_loss: -1.3753e+00 - val_z_latents_loss: 2.6878
# Epoch 48/1000000
#
# Epoch 00048: loss did not improve from 5863.23145
# 5000/5000 - 200s - loss: 5868.2974 - x_logits_loss: 5865.3784 - x_logpdf_loss: -1.3707e+00 - z_latents_loss: 2.8312 - val_loss: 2621.4482 - val_x_logits_loss: 2619.0327 - val_x_logpdf_loss: -1.3730e+00 - val_z_latents_loss: 2.6211
# Epoch 49/1000000
#
# Epoch 00049: loss improved from 5863.23145 to 5862.23438, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 199s - loss: 5862.2344 - x_logits_loss: 5859.3081 - x_logpdf_loss: -1.3716e+00 - z_latents_loss: 2.8234 - val_loss: 2659.1533 - val_x_logits_loss: 2656.7549 - val_x_logpdf_loss: -1.3658e+00 - val_z_latents_loss: 2.6021
# Epoch 50/1000000
#
# Epoch 00050: loss improved from 5862.23438 to 5855.80420, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 199s - loss: 5855.8042 - x_logits_loss: 5852.8726 - x_logpdf_loss: -1.3700e+00 - z_latents_loss: 2.8173 - val_loss: 2581.5432 - val_x_logits_loss: 2578.9546 - val_x_logpdf_loss: -1.3705e+00 - val_z_latents_loss: 2.6921
# Epoch 51/1000000
#
# Epoch 00051: loss did not improve from 5855.80420
# 5000/5000 - 199s - loss: 5857.2427 - x_logits_loss: 5854.2866 - x_logpdf_loss: -1.3681e+00 - z_latents_loss: 2.8098 - val_loss: 2553.4678 - val_x_logits_loss: 2550.6704 - val_x_logpdf_loss: -1.3659e+00 - val_z_latents_loss: 2.7490
# Epoch 52/1000000
#
# Epoch 00052: loss did not improve from 5855.80420
# 5000/5000 - 197s - loss: 5857.6885 - x_logits_loss: 5854.7368 - x_logpdf_loss: -1.3694e+00 - z_latents_loss: 2.8006 - val_loss: 2971.6790 - val_x_logits_loss: 2968.1743 - val_x_logpdf_loss: -1.3251e+00 - val_z_latents_loss: 3.3494
# Epoch 53/1000000
#
# Epoch 00053: loss did not improve from 5855.80420
# 5000/5000 - 198s - loss: 5871.7666 - x_logits_loss: 5868.8237 - x_logpdf_loss: -1.3688e+00 - z_latents_loss: 2.7918 - val_loss: 2593.0071 - val_x_logits_loss: 2590.3135 - val_x_logpdf_loss: -1.3802e+00 - val_z_latents_loss: 2.6911
# Epoch 54/1000000
#
# Epoch 00054: loss improved from 5855.80420 to 5852.44824, saving model to /content/drive/My Drive/Results/pokemonVAE_Dense_reconst_1ell_05psnr/var_save_dir
# 5000/5000 - 202s - loss: 5852.4482 - x_logits_loss: 5849.4907 - x_logpdf_loss: -1.3683e+00 - z_latents_loss: 2.7845 - val_loss: 10173.7998 - val_x_logits_loss: 10162.4844 - val_x_logpdf_loss: -1.3570e+00 - val_z_latents_loss: 8.0050
# Epoch 55/1000000
#
# Epoch 00055: loss did not improve from 5852.44824
# 5000/5000 - 198s - loss: 5880.9043 - x_logits_loss: 5877.9419 - x_logpdf_loss: -1.3713e+00 - z_latents_loss: 2.7807 - val_loss: 2759.4841 - val_x_logits_loss: 2756.6653 - val_x_logpdf_loss: -1.3827e+00 - val_z_latents_loss: 2.9544
# Epoch 56/1000000
#
# Epoch 00056: loss did not improve from 5852.44824
# 5000/5000 - 199s - loss: 5865.2441 - x_logits_loss: 5862.2822 - x_logpdf_loss: -1.3714e+00 - z_latents_loss: 2.7746 - val_loss: 2732.9341 - val_x_logits_loss: 2729.8582 - val_x_logpdf_loss: -1.3811e+00 - val_z_latents_loss: 2.9781
# Epoch 57/1000000
#
# Epoch 00057: loss did not improve from 5852.44824
# 5000/5000 - 198s - loss: 5863.2070 - x_logits_loss: 5860.2417 - x_logpdf_loss: -1.3683e+00 - z_latents_loss: 2.7673 - val_loss: 4293.1421 - val_x_logits_loss: 4286.6484 - val_x_logpdf_loss: -1.3706e+00 - val_z_latents_loss: 6.1936
# Epoch 58/1000000
#
# Epoch 00058: loss did not improve from 5852.44824
# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## inception_score

# %%
from evaluation.generativity_metrics.inception_metrics import inception_score

# %%
is_mean, is_sigma = inception_score(ae, tolerance_threshold=1e-6, max_iteration=300)
print(f'inception_score mean: {is_mean.compute()}, sigma: {is_sigma.compute()}')
# Out:
# calculating the inception_score mean ...
# WARNING:tensorflow:Model was constructed with shape (None, 75, 75, 3) for input Tensor("input_1:0", shape=(None, 75, 75, 3), dtype=float32), but it was called on an input with incompatible shape (None, 100, 100, 3).
# 300it [2:13:03, 26.08s/it]
# calculating the inception_score sigma ...
# /usr/local/lib/python3.6/dist-packages/dask/array/routines.py:780: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)
# 0it [00:00, ?it/s]/usr/local/lib/python3.6/dist-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 300it [2:10:59, 26.37s/it]
# inception_score mean: [3.18035947e+84], sigma: 1.2701561237295391e+169

# %% [markdown]
# ## Frechet_inception_distance

# %%
from evaluation.generativity_metrics.inception_metrics import frechet_inception_distance

# %%
fis_score = frechet_inception_distance(ae, train_generator.as_numpy_iterator(), 
                                       tolerance_threshold=1e-6, 
                                       max_iteration=300, 
                                       batch_size=32)

# %%
print(f'frechet inception distance: {fis_score.compute()}')

# %% [markdown]
# ## perceptual_path_length_score

# %%
from evaluation.generativity_metrics.perceptual_path_length import perceptual_path_length_score

# %%
ppl_mean_score = perceptual_path_length_score(ae, train_generator.as_numpy_iterator(), 
                                              tolerance_threshold=1e-6, 
                                              max_iteration=300, 
                                              batch_size=32)
print(f'perceptual path length score: {ppl_mean_score}')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-38-57de301af196> in <module>()
#       2                                               tolerance_threshold=1e-6,
#       3                                               max_iteration=300,
# ----> 4                                               batch_size=32)
#       5 print(f'perceptual path length score: {ppl_mean_score}')
#
# /content/Generative_Models/evaluation/generativity_metrics/perceptual_path_length.py in perceptual_path_length_score(model, data_generator, tolerance_threshold, max_iteration, batch_size)
#      72     ppl_mean = bootstrapping_additive(
#      73         data_generator=model_random_images_generator(), func=delayed(calculate_distances), \
# ---> 74         stopping_func=stopping_fn, tolerance_threshold=tolerance_threshold, max_iteration=max_iteration
#      75     )
#      76
#
# /content/Generative_Models/evaluation/generativity_metrics/shared_api.py in bootstrapping_additive(data_generator, func, stopping_func, tolerance_threshold, max_iteration)
#      29
#      30 def bootstrapping_additive(data_generator, func, stopping_func, tolerance_threshold=1e-6, max_iteration=50):
# ---> 31     data = next(data_generator)
#      32     outputs = [func(data).compute()]
#      33     results = stopping_func(outputs)
#
# /content/Generative_Models/evaluation/generativity_metrics/perceptual_path_length.py in model_random_images_generator()
#      52         while True:
#      53             # Generate latents from the data
# ---> 54             latents_real = model.encode(next(data_generator)['images'])
#      55
#      56             # Generate random latents and interpolation t-values.
#
# /content/Generative_Models/training/autoencoding_basic/autoencoders/VAE.py in encode(self, x)
#      21     # autoencoder function
#      22     def encode(self, x):
# ---> 23         return self.__encode__(inference_inputs={'x_mean': x, 'x_logvariance': x})['z_latents']
#      24
#      25     def __init_autoencoder__(self, **kwargs):
#
# /content/Generative_Models/training/autoencoding_basic/autoencoders/autoencoder.py in __encode__(self, **kwargs)
#     153         kwargs['model']  = self.get_variable
#     154         kwargs['latents_shape'] = (self.batch_size, self.latents_dim)
# --> 155         return self.encode_fn(**kwargs)
#     156
#     157     # autoencoder function
#
# /content/Generative_Models/graphs/basics/VAE_graph.py in encode_fn(**kwargs)
#      21     inputs = kwargs['inference_inputs']
#      22     latents_shape = kwargs['latents_shape']
# ---> 23     mean, logvariance = model('inference_mean', [inputs['x_mean']]), model('inference_logvariance', [inputs['x_logvariance']])
#      24     z = reparameterize(mean, logvariance, latents_shape)
#      25     return {
#
# /content/Generative_Models/training/autoencoding_basic/autoencoders/autoencoder.py in get_variable(self, var_name, param)
#      39
#      40     def get_variable(self, var_name, param):
# ---> 41         return self.get_variables()[var_name](*param)
#      42
#      43     def __init_autoencoder__(self, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     384     """
#     385     return self._run_internal_graph(
# --> 386         inputs, training=training, mask=mask)
#     387
#     388   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     506
#     507         args, kwargs = node.map_arguments(tensor_dict)
# --> 508         outputs = node.layer(*args, **kwargs)
#     509
#     510         # Update tensor_dict.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py in call(self, inputs)
#    1196         self.bias,
#    1197         self.activation,
# -> 1198         dtype=self._compute_dtype_object)
#    1199
#    1200   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/ops/core.py in dense(inputs, kernel, bias, activation, dtype)
#      51       outputs = sparse_ops.sparse_tensor_dense_matmul(inputs, kernel)
#      52     else:
# ---> 53       outputs = gen_math_ops.mat_mul(inputs, kernel)
#      54   # Broadcast kernel to inputs.
#      55   else:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5622       return _result
#    5623     except _core._NotOkStatusException as e:
# -> 5624       _ops.raise_from_not_ok_status(e, name)
#    5625     except _core._FallbackException:
#    5626       pass
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Matrix size-incompatible: In[0]: [10,4000000], In[1]: [250000,100] [Op:MatMul]

# %% [markdown]
# ## precision score

# %%
from evaluation.generativity_metrics.precision_recall import precision_score

# %%
_precision_score = precision_score(ae,  train_generator.as_numpy_iterator(), 
                                   tolerance_threshold=1e-6, 
                                   max_iteration=300)
print(f'precision score: {_precision_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00254917s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00214124s
# precision score: [0.]

# %% [markdown]
# ## recall score

# %%
from evaluation.generativity_metrics.precision_recall import recall_score

# %%
_recall_score = recall_score(ae, train_generator.as_numpy_iterator(), tolerance_threshold=1e-6, max_iteration=300)
print(f'recall score: {_recall_score}')
# Out:
# /content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# 0it [00:00, ?it/s]/content/Generative_Models/evaluation/generativity_metrics/precision_recall.py:84: RuntimeWarning: invalid value encountered in true_divide
#   realism_score[begin1:end1] = self.D[nearest_indices[begin1:end1], 0] / np.min(distance_batch[0:end1-begin1, :], axis=1)
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00267744s
# Evaluating k-NN precision and recall with 10 samples...
# Done evaluation in: 0.00235796s
# recall score: [1.]

# %% [markdown]
# # Image Generation

# %% [markdown]
# ## image reconstruction

# %% [markdown]
# ### Training dataset

# %%
from training.generators.from_images.image_generation_testing import reconstruct_from_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 78.70it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'reconstruct_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

reconstruct_from_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 37.38it/s]

# %% [markdown]
# ## with Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_like_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_training_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, train_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 49.00it/s]

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'generate_testing_images_like_a_batch_dir')
create_if_not_exist(save_dir)

generate_images_like_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 10it [00:00, 44.15it/s]

# %% [markdown]
# ### Complete Randomness

# %%
from training.generators.from_images.image_generation_testing import generate_images_randomly

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'random_synthetic_dir')
create_if_not_exist(save_dir)

generate_images_randomly(ae, save_dir)
# Out:
# 32it [00:00, 78.34it/s]

# %%
from training.generators.from_images.image_generation_testing import interpolate_a_batch

# %%
from utils.data_and_files.file_utils import create_if_not_exist
save_dir = os.path.join(experiments_dir, 'interpolate_dir')
create_if_not_exist(save_dir)

interpolate_a_batch(ae, val_generator.as_numpy_iterator(), save_dir)
# Out:
# 3it [00:00, 26.94it/s]
# 10it [00:00, 26.03it/s]
# 3it [00:00, 27.94it/s]
# 10it [00:00, 26.98it/s]
# 3it [00:00, 28.54it/s]
# 10it [00:00, 27.73it/s]
# 3it [00:00, 28.11it/s]
# 10it [00:00, 27.62it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# 10it [00:00, 26.21it/s]
